# %% [markdown]
# Data Source: https://data.cityofchicago.org/Community-Economic-Development/Business-Licenses/r5kz-chrr

# %%
crime_df2['Community'].value_counts(dropna = False).sort_index()

# %%
# Reading in chicago business licenses file
license_df = pd.read_csv('Business_Licenses.csv')
# Out:
# C:\Users\Anita\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (9,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
license_df.head()
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    22308-20060816     1723393           29481            1
# 1  1620668-20160516     2455262          295026            1
# 2  2368602-20160616     2460909          291461            3
# 3  2060891-20141016     2353257          357247            1
# 4  1144216-20070516     1804790             147           63
#
#                           LEGAL NAME             DOING BUSINESS AS NAME  \
# 0              BELL OIL TERMINAL INC              Bell Oil Terminal LLC
# 1              BUCCI BIG & TALL INC.              BUCCI BIG & TALL INC.
# 2             PROJECT: VISION , INC.             PROJECT : VISION , INC
# 3  FOLASHADE'S CLEANING SERVICE INC.  FOLASHADE'S CLEANING SERVICE INC.
# 4                       WALGREEN CO.                  Walgreens # 05192
#
#                      ADDRESS     CITY STATE ZIP CODE  WARD  PRECINCT  \
# 0       3741 S PULASKI RD  1  CHICAGO    IL    60623  14.0       NaN
# 1         558 W ROOSEVELT RD  CHICAGO    IL    60607  25.0      28.0
# 2      2301 S ARCHER AVE 1 1  CHICAGO    IL    60616  25.0      18.0
# 3     1965  BERNICE RD 1 1SW  LANSING    IL    60438   NaN       NaN
# 4  9148 S COMMERCIAL AVE 1ST  CHICAGO    IL    60617  10.0      25.0
#
#   WARD PRECINCT  POLICE DISTRICT  LICENSE CODE       LICENSE DESCRIPTION  \
# 0           14-              8.0          1010  Limited Business License
# 1         25-28              1.0          1010  Limited Business License
# 2         25-18              9.0          1625                   Raffles
# 3           NaN              NaN          1010  Limited Business License
# 4         10-25              4.0          1010  Limited Business License
#
#   BUSINESS ACTIVITY ID                                  BUSINESS ACTIVITY  \
# 0                  NaN                                                NaN
# 1                  911     Retail Sales of Clothing / Accessories / Shoes
# 2                  720  Not-For-Profit Selling Raffles for Prizes of $...
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
#
#    LICENSE NUMBER APPLICATION TYPE APPLICATION CREATED DATE  \
# 0         22308.0            RENEW                      NaN
# 1       1620668.0            RENEW                      NaN
# 2       2368602.0            RENEW                      NaN
# 3       2060891.0            RENEW                      NaN
# 4       1144216.0            RENEW                      NaN
#
#   APPLICATION REQUIREMENTS COMPLETE PAYMENT DATE CONDITIONAL APPROVAL  \
# 0                        06/21/2006   08/10/2006                    N
# 1                        03/15/2016   05/18/2016                    N
# 2                        04/15/2016   06/21/2016                    N
# 3                        08/15/2014   04/01/2016                    N
# 4                        03/23/2007   05/10/2007                    N
#
#   LICENSE TERM START DATE LICENSE TERM EXPIRATION DATE  \
# 0              08/16/2006                   08/15/2007
# 1              05/16/2016                   05/15/2018
# 2              06/16/2016                   06/15/2017
# 3              10/16/2014                   10/15/2016
# 4              05/16/2007                   05/15/2008
#
#   LICENSE APPROVED FOR ISSUANCE DATE ISSUED LICENSE STATUS  \
# 0                    08/10/2006  08/11/2006            AAI
# 1                    05/18/2016  08/30/2016            AAI
# 2                    06/21/2016  06/22/2016            AAC
# 3                    04/01/2016  04/01/2016            AAI
# 4                    05/10/2007  05/11/2007            AAI
#
#   LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 0                        NaN   NaN  41.825320 -87.723960
# 1                        NaN   NaN  41.867339 -87.641590
# 2                 08/30/2016   NaN  41.850843 -87.638734
# 3                        NaN  38.0  41.951316 -87.678586
# 4                        NaN   5.0  41.728622 -87.551366
#
#                                   LOCATION
# 0  (41.82531992987547, -87.72395999659746)
# 1  (41.86733856638269, -87.64159005699716)
# 2  (41.85084294374687, -87.63873424399071)
# 3  (41.95131555606832, -87.67858578019546)
# 4  (41.72862173556932, -87.55136646594693)

# %%
license_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954489 entries, 0 to 954488
# Data columns (total 34 columns):
# ID                                   954489 non-null object
# LICENSE ID                           954489 non-null int64
# ACCOUNT NUMBER                       954489 non-null int64
# SITE NUMBER                          954489 non-null int64
# LEGAL NAME                           954485 non-null object
# DOING BUSINESS AS NAME               954439 non-null object
# ADDRESS                              954489 non-null object
# CITY                                 954486 non-null object
# STATE                                954477 non-null object
# ZIP CODE                             954091 non-null object
# WARD                                 884245 non-null float64
# PRECINCT                             856124 non-null float64
# WARD PRECINCT                        884418 non-null object
# POLICE DISTRICT                      861325 non-null float64
# LICENSE CODE                         954489 non-null int64
# LICENSE DESCRIPTION                  954489 non-null object
# BUSINESS ACTIVITY ID                 424483 non-null object
# BUSINESS ACTIVITY                    424483 non-null object
# LICENSE NUMBER                       954488 non-null float64
# APPLICATION TYPE                     954489 non-null object
# APPLICATION CREATED DATE             221277 non-null object
# APPLICATION REQUIREMENTS COMPLETE    936187 non-null object
# PAYMENT DATE                         932595 non-null object
# CONDITIONAL APPROVAL                 954489 non-null object
# LICENSE TERM START DATE              951812 non-null object
# LICENSE TERM EXPIRATION DATE         954404 non-null object
# LICENSE APPROVED FOR ISSUANCE        907148 non-null object
# DATE ISSUED                          954489 non-null object
# LICENSE STATUS                       954489 non-null object
# LICENSE STATUS CHANGE DATE           65242 non-null object
# SSA                                  247936 non-null float64
# LATITUDE                             881398 non-null float64
# LONGITUDE                            881398 non-null float64
# LOCATION                             881398 non-null object
# dtypes: float64(7), int64(4), object(23)
# memory usage: 247.6+ MB

# %%
# Checking null legal names
license_df[(license_df['LEGAL NAME'].isnull())]
# Out:
#                      ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER LEGAL NAME  \
# 85662  2054727-20140916     2347511          356209            1        NaN
# 85982  2054727-20100827     2054727          356209            1        NaN
# 86058  2054727-20120916     2176737          356209            1        NaN
# 87212  2054727-20160916     2481571          356209            1        NaN
#
#        DOING BUSINESS AS NAME        ADDRESS       CITY STATE ZIP CODE  WARD  \
# 85662  ENGAGING SCHOOLS, INC.  23  GARDEN ST  CAMBRIDGE    MA    02138   NaN
# 85982  ENGAGING SCHOOLS, INC.  23  GARDEN ST  CAMBRIDGE    MA    02138   NaN
# 86058  ENGAGING SCHOOLS, INC.  23  GARDEN ST  CAMBRIDGE    MA    02138   NaN
# 87212  ENGAGING SCHOOLS, INC.  23  GARDEN ST  CAMBRIDGE    MA    02138   NaN
#
#        PRECINCT WARD PRECINCT  POLICE DISTRICT  LICENSE CODE  \
# 85662       NaN           NaN              NaN          1010
# 85982       NaN           NaN              NaN          1010
# 86058       NaN           NaN              NaN          1010
# 87212       NaN           NaN              NaN          1010
#
#             LICENSE DESCRIPTION BUSINESS ACTIVITY ID BUSINESS ACTIVITY  \
# 85662  Limited Business License                  NaN               NaN
# 85982  Limited Business License                  NaN               NaN
# 86058  Limited Business License                  NaN               NaN
# 87212  Limited Business License                  NaN               NaN
#
#        LICENSE NUMBER APPLICATION TYPE APPLICATION CREATED DATE  \
# 85662       2054727.0            RENEW                      NaN
# 85982       2054727.0            ISSUE                      NaN
# 86058       2054727.0            RENEW                      NaN
# 87212       2054727.0            RENEW                      NaN
#
#       APPLICATION REQUIREMENTS COMPLETE PAYMENT DATE CONDITIONAL APPROVAL  \
# 85662                        07/15/2014   09/11/2014                    N
# 85982                        08/27/2010   08/27/2010                    N
# 86058                        07/16/2012   08/22/2012                    N
# 87212                        07/15/2016   03/03/2017                    N
#
#       LICENSE TERM START DATE LICENSE TERM EXPIRATION DATE  \
# 85662              09/16/2014                   09/15/2016
# 85982              08/27/2010                   09/15/2012
# 86058              09/16/2012                   09/15/2014
# 87212              09/16/2016                   09/15/2018
#
#       LICENSE APPROVED FOR ISSUANCE DATE ISSUED LICENSE STATUS  \
# 85662                    09/11/2014  09/12/2014            AAI
# 85982                    08/27/2010  08/27/2010            AAI
# 86058                    08/22/2012  08/23/2012            AAI
# 87212                    03/03/2017  03/07/2017            AAI
#
#       LICENSE STATUS CHANGE DATE  SSA  LATITUDE  LONGITUDE LOCATION
# 85662                        NaN  NaN       NaN        NaN      NaN
# 85982                        NaN  NaN       NaN        NaN      NaN
# 86058                        NaN  NaN       NaN        NaN      NaN
# 87212                        NaN  NaN       NaN        NaN      NaN

# %% [markdown]
# The licenses with missing legal names do not have anything to do with liquor, so I will drop them.

# %%
# Dropping rows with null legal name
license_df.dropna(subset=['LEGAL NAME'], inplace=True)

# %%
# Making all letters capitalized in 'Legal Name'
license_df['LEGAL NAME'] = license_df['LEGAL NAME'].apply(lambda name: name.upper())

# %%
# Searching for liquor stores
license_df['LEGAL NAME'][license_df['LEGAL NAME'].str.contains('LIQUOR|SPIRITS|WINE|ALCOHOL')]
# Out:
# 555                     FLICKINGER FINE WINE, INC.
# 1653                         DANNY'S LIQUORS, INC.
# 1727                     ALTGELD GARDEN LIQUOR INC
# 1743                         ASHLAND LIQUORS, INC.
# 2401                 GREEN OAK FOOD & LIQUOR, INC.
# 2827                   LATIN GROCERY & LIQUOR, INC
# 4170                    LAKE & WELLS FOOD & LIQUOR
# 6436                       ALIZE FOOD & LIQUOR INC
# 8193                            AIDA FOOD & LIQUOR
# 9080                            4424 LIQUORS, INC.
# 9475                         WHIPPLE LIQUORS, INC.
# 9654                   1155 N. WELLS LIQUORS, INC.
# 9783           HOUSTON'S LIQUOR & FOOD STORE, INC.
# 10618                      DIA FOOD & LIQUOR, INC.
# 11505                 7901 LIQUORS & GROCERY, INC.
# 11687                         TONY'S FOOD & LIQUOR
# 11797                     MR G'S FOOD & LIQUOR INC
# 12185                    K & C FOOD & LIQUORS INC.
# 12382              ONE ELEVEN FOOD & LIQUORS, INC.
# 12520                   ABBASSI FOOD & LIQUORS INC
# 12724                 BROTHERS FOOD & LIQUOR, INC.
# 13380                  THOMAS FOOD & LIQUORS, INC.
# 13585                    KEYSTONE WINE AND SPIRITS
# 13834     CHAMUNDA CONVENIENT FOODS & LIQUOR, INC.
# 13897                     N.W. FOOD & LIQUOR, INC.
# 14224                 SAGINAW WINE & LIQUORS, INC.
# 14365                     I. S. FOOD & LIQUOR INC.
# 14408                          DYNAMIC LIQUORS INC
# 14579                       TOP-LESS LIQUORS, INC.
# 14616                     I. S. FOOD & LIQUOR INC.
#                             ...
# 953631                         DAMEN LIQUORS, INC.
# 953661                     Z & S FOOD & LIQUOR INC
# 953709                    HANA FOOD & LIQUOR, INC.
# 953735                   ANDY'S LIQUOR & FOOD INC.
# 953740               ALMUFLIHI FOOD & LIQUOR, INC.
# 953801               THREE SON'S FOOD & LIQUOR INC
# 953872                 SAM AND JOE'S LIQUORS, INC.
# 953876             FOUR BROTHERS FOOD & LIQUOR INC
# 953975                  E R & J FOOD & LIQUOR, INC
# 953981                J. FERAS FOOD & LIQUOR, INC.
# 954111               SHERIDAN IRVING L LIQUORS INC
# 954125                          LIQUOR DEPOT, INC.
# 954133                      TRIER'S  LIQUORS, INC.
# 954142                           J & B LIQUORS INC
# 954143                  HADDAD FOOD & LIQUOR, INC.
# 954160                         CAVITOS LIQUORS INC
# 954165                    RAMMEY FOOD & LIQUOR INC
# 954179                     FINE WINE BROKERS, INC.
# 954181                7901 LIQUORS & GROCERY, INC.
# 954191               MARY'S DISCOUNT FOOD & LIQUOR
# 954253                BROTHERS FOOD & LIQUOR, INC.
# 954266                   HANI'S LIQUOR STATION INC
# 954302                           J & B LIQUORS INC
# 954319                   FERAS FOOD & LIQUOR, INC.
# 954382                        BUY LOW LIQUORS INC.
# 954386                  CAMPBELL FOOD & LIQUOR INC
# 954401                SAGINAW WINE & LIQUORS, INC.
# 954426           PAIRED WINE COMPANY CHICAGO, INC.
# 954439                   S & B FOOD & LIQUOR, INC.
# 954465                CRU CAFE & WINE BAR, LIMITED
# Name: LEGAL NAME, Length: 13552, dtype: object

# %%
# Creating df of liquor stores
liquor_df = license_df[license_df['LEGAL NAME'].str.contains('LIQUOR|SPIRITS|WINE|ALCOHOL')]

# %%
liquor_df.head()
# Out:
#                     ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 555   1577539-20060816     1734460          287993            1
# 1653     1118-20060216     1654809           24160            1
# 1727    32895-20070816     1825750           14600            1
# 1743    21457-20110716     2095696           63338            1
# 2401    33091-20070216     1774457            8468            1
#
#                          LEGAL NAME       DOING BUSINESS AS NAME  \
# 555      FLICKINGER FINE WINE, INC.         FLICKINGER FINE WINE
# 1653          DANNY'S LIQUORS, INC.              DANNY'S LIQUORS
# 1727      ALTGELD GARDEN LIQUOR INC    ALTGELD GARDEN LIQUOR INC
# 1743          ASHLAND LIQUORS, INC.           ROTHSCHILD LIQUORS
# 2401  GREEN OAK FOOD & LIQUOR, INC.  GREEN OAK FOOD & LIQUOR INC
#
#                             ADDRESS     CITY STATE ZIP CODE  WARD  PRECINCT  \
# 555   1600 S STEWART AVE 5TH & BSMT  CHICAGO    IL    60616  25.0       6.0
# 1653       3018 N MILWAUKEE AVE 1ST  CHICAGO    IL    60618  30.0      25.0
# 1727          13118 S ELLIS AVE 1ST  CHICAGO    IL    60827   9.0      42.0
# 1743         1532 W CHICAGO AVE 1ST  CHICAGO    IL    60642   1.0      40.0
# 2401              956 N LARRABEE ST  CHICAGO    IL    60610  27.0      21.0
#
#      WARD PRECINCT  POLICE DISTRICT  LICENSE CODE       LICENSE DESCRIPTION  \
# 555           25-6             12.0          1010  Limited Business License
# 1653         30-25             25.0          1010  Limited Business License
# 1727          9-42              5.0          1010  Limited Business License
# 1743          1-40             12.0          1010  Limited Business License
# 2401         27-21             18.0          1010  Limited Business License
#
#      BUSINESS ACTIVITY ID BUSINESS ACTIVITY  LICENSE NUMBER APPLICATION TYPE  \
# 555                   NaN               NaN       1577539.0            RENEW
# 1653                  NaN               NaN          1118.0            RENEW
# 1727                  NaN               NaN         32895.0            RENEW
# 1743                  NaN               NaN         21457.0            RENEW
# 2401                  NaN               NaN         33091.0            RENEW
#
#      APPLICATION CREATED DATE APPLICATION REQUIREMENTS COMPLETE PAYMENT DATE  \
# 555                       NaN                        06/21/2006   07/18/2006
# 1653                      NaN                        12/21/2005   02/10/2006
# 1727                      NaN                        06/21/2007   08/13/2007
# 1743                      NaN                        05/16/2011   07/08/2011
# 2401                      NaN                        12/20/2006   02/13/2007
#
#      CONDITIONAL APPROVAL LICENSE TERM START DATE  \
# 555                     N              08/16/2006
# 1653                    N              02/16/2006
# 1727                    N              08/16/2007
# 1743                    N              07/16/2011
# 2401                    N              02/16/2007
#
#      LICENSE TERM EXPIRATION DATE LICENSE APPROVED FOR ISSUANCE DATE ISSUED  \
# 555                    08/15/2007                    07/18/2006  07/19/2006
# 1653                   02/15/2007                    02/10/2006  02/14/2006
# 1727                   07/15/2008                    08/13/2007  08/13/2007
# 1743                   07/15/2013                    07/08/2011  07/11/2011
# 2401                   02/15/2008                    02/13/2007  02/13/2007
#
#      LICENSE STATUS LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 555             AAI                        NaN   NaN  41.859977 -87.637946
# 1653            AAI                        NaN   NaN  41.935989 -87.718982
# 1727            AAI                        NaN   NaN  41.656753 -87.597599
# 1743            AAC                 08/06/2012  29.0  41.896199 -87.666257
# 2401            AAI                        NaN   NaN  41.900361 -87.643236
#
#                                       LOCATION
# 555   (41.859977210463654, -87.63794616945249)
# 1653   (41.93598865891675, -87.71898231267689)
# 1727   (41.65675265668745, -87.59759858587499)
# 1743   (41.89619851505597, -87.66625727462089)
# 2401    (41.90036123056518, -87.6432364056876)

# %%
# Checking out the names of the liquor stores
set(liquor_df['LEGAL NAME'])
# Out:
# {"1000 LIQUOR'S, INC.",
#  '1155 N. WELLS LIQUORS, INC.',
#  '115TH ST FOOD & LIQUORS INC',
#  '12 ROTHSCHILD LIQUOR MART, INC.',
#  '1208 LIQUORS, INC.',
#  '2000 WEST MADISON LIQUOR CORP',
#  '2944 WEST 47TH STREET LIQUOR MART, INC.',
#  '301 PULASKI FOOD & LIQUOR, INC.',
#  '3400 FOOD & LIQUOR INC',
#  '4424 LIQUORS, INC.',
#  '47TH ST FOOD & LIQUOR INC',
#  '4801 CHICAGO PRESTIGE FOOD & LIQUOR, INC.',
#  '51ST EXPRESS FOOD & LIQUOR INC',
#  '57TH STREET WINES LLC',
#  '63RD FOOD & LIQUOR INC.',
#  '67TH ONE STOP FOOD & LIQUOR, INC.',
#  '71ST & STATE FOOD & LIQUOR, INC.',
#  '7400 SOUTH HALSTED FOOD AND LIQUORS, INC.',
#  '7901 LIQUORS & GROCERY, INC.',
#  '79TH M & S FOOD & LIQUOR, INC.',
#  '8258 HALSTED FOOD & LIQUORS INC',
#  '87 SOUTH ROTHSCHILD LIQUORS, INC.',
#  '8900 COMMERCIAL FOOD & LIQUOR, INC.',
#  '8900 LIQUORS, INC.',
#  '9300 FOOD & LIQUOR INC',
#  '932 ADDISION LIQUORS INC.',
#  '95TH FOOD & LIQUOR INC',
#  'A & G FOOD & LIQUOR INC',
#  'A & G LIQUORS, INC.',
#  'A & O FOOD & LIQUOR INC.',
#  'A & Q FOOD & LIQUOR, INC.',
#  'A AND P FOOD AND LIQUOR INC.',
#  'A&D LIQUORS & DELI, INC.',
#  'A&E FOOD AND LIQUOR CORPORATION',
#  'A&K PRESTIGE FOOD & LIQUOR, INC.',
#  'A-ONE FOOD & LIQUOR INC',
#  'A.G.H. FOOD AND LIQUOR, INC.',
#  'AB FOOD AND LIQUOR INC',
#  'ABBASCO FOOD & LIQUOR INC.',
#  'ABBASSI FOOD & LIQUORS INC',
#  'ABH FOOD & LIQUOR INC',
#  "ABIE'S FOOD & LIQUOR INC.",
#  'ABOUD FOOD & LIQUOR INC',
#  "ADAM'S FOOD / LIQUOR INC.",
#  'ADDISON FOOD & LIQUOR, INC',
#  'AFRICAN SUPERMARKET AND LIQUORS, INC.',
#  'AIDA FOOD & LIQUOR',
#  'AJ LIQUOR INC',
#  'ALBANY FOOD & LIQUORS, INC.',
#  'ALBAWRA FOOD & LIQUOR, INC.',
#  'ALCOHOLICS ANONYMOUS CHICAGO AREA SERVICE OFFICE',
#  'ALEX LIQUORS & DELI LIMITED',
#  'ALIZE FOOD & LIQUOR INC',
#  'ALL STAR FOOD & LIQUORS INC',
#  'ALMUFLIHI FOOD & LIQUOR, INC.',
#  'ALPHA FOOD & LIQUORS INC',
#  'ALTGELD GARDEN LIQUOR INC',
#  'AM DELI AND LIQUOR INC.',
#  'AMERICAN INSTITUTE OF WINE & FOOD - CHICAGO CHAPTER',
#  'AMERICAN WAY FOOD & LIQUOR INC',
#  'AMPERSAND WINE BAR LLC',
#  "ANDY'S LIQUOR & FOOD INC.",
#  'ANJANI FOOD & LIQUOR INC.',
#  "ANNA'S J FOOD & LIQUORS INC",
#  'ARCADIA FOOD & LIQUOR INC.',
#  'ARCADIA LIQUORS INC',
#  'ARISTO FOOD & LIQUOR,  INC.',
#  'ARKANSAS MISSISSIPPI LIQUORS,',
#  'ARMITAGE BAR & LIQUOR, INC',
#  'ARMITAGE GOLD STAR LIQUOR, INC.',
#  'ARTS N SPIRITS, LLC',
#  'ASHLAND LIQUOR & FOOD, INC.',
#  'ASHLAND LIQUORS, INC.',
#  'ATLANTA FOOD & LIQUOR INC',
#  'ATSHAN FOOD & LIQUOR INC.',
#  'B & B GROCERY AND LIQUORS, INC.',
#  'B. K. LIQUORS, INC.',
#  'BABEL LIQUORS, INC.',
#  'BANNER LIQUOR & TAP, INC.',
#  'BASIL FOOD & LIQUOR INC.',
#  'BAY AREA WINE PROJECT INC.',
#  'BC LIQUOR INC.',
#  'BEL-PARK LIQUORS INC.',
#  'BEL-PORT FOOD & LIQUOR INC',
#  'BELMONT FOOD & LIQUOR, INC.',
#  'BELMONT LIQUORS INC',
#  'BELMONTE FOOD, WINE & SPIRITS, INC.',
#  'BENNETT & BENNETT SPECIAL WINE',
#  'BENNETT & BENNETT, SPECIAL WINES INC.',
#  'BEST BARBECUE & LIQUOR INC',
#  'BEVERLY FOOD & LIQUOR INC',
#  "BIG O'LIQUOR & FOOD STORE INC",
#  "BIG SAM'S FOOD & LIQUOR, INC.",
#  'BLUE BIRD LIQUORS,  INC.',
#  'BON SONG LIQUORS INC',
#  'BOOGIES BEER AND WINE, LLC',
#  'BOULEVARD FOOD & LIQUOR LLC',
#  'BP FOOD & LIQUOR, INC.',
#  'BRANDYWINE PROPERTIES MANAGEMENT LP',
#  'BRAVO FOOD & LIQUOR LLC',
#  'BRISTOL LIQUORS INC',
#  'BROTHERS FOOD & LIQUOR, INC.',
#  'BROWN BASKET FOOD & LIQUORS IN',
#  'BROWN LIQUORS, INC.',
#  'BUCKTOWN LIQUORS, INC.',
#  'BUDDIES FOOD & LIQUORS, INC.',
#  "BUDDY'S WINE & SPIRITS, INC.",
#  'BUTCHER FOOD & LIQUOR, INC.',
#  'BUY LOW LIQUORS INC.',
#  'C & K FOOD & LIQUOR, INC.',
#  'C & K LIQUORS, INC.',
#  'CALDWELL FOOD & LIQUOR INC.,',
#  'CALS 400 LIQUOR INC',
#  'CALUMET FOOD & LIQUOR INC',
#  'CAMPBELL FOOD & LIQUOR INC',
#  "CAPONE'S LIQUORS & FOOD, INC.",
#  'CAVITOS LIQUORS INC',
#  'CENTRAL LIQUOR MART INC',
#  'CENTRAL LIQUORS INC.',
#  'CHAMUNDA CONVENIENT FOODS & LIQUOR, INC.',
#  'CHATEAU LIQUORS & GOURMET FOOD',
#  'CHAZ FOOD & LIQUOR, INC.',
#  'CHEVALIER FINE WINES, INC.',
#  'CHICAGO LIQUOR HOUSE INC.',
#  'CHICAGO LIQUOR, INC.',
#  'CHICAGO PRESTIGE LIQUORS INC',
#  'CHICAGO WINE SOURCE, LTD',
#  "CHICAGO'S WINE & CHOCOLATE CAFES LLC",
#  'CHINA PLACE LIQUOR CITY, INC.',
#  "CHIP'S LIQUOR, INC.",
#  "CHRIST'S TOWN & COUNTRY LIQUOR MART, INC.",
#  'CICERO-NORTH AVENUE FOOD & LIQUOR INC.',
#  'CINCO HERMANAS FOOD & LIQUOR INC.',
#  'CITY WINERY CHICAGO, LLC',
#  'CLARK SUPER FOOD MARKET AND LIQUORS, INC.',
#  'CLARK-FOSTER LIQUORS INC',
#  'CLASSIC WINE & SPIRITS INC',
#  'COIN LIQUOR & GROCERY INC',
#  'COLONY FOOD & LIQUOR, INC.',
#  'COLUMBUS WINE & SPIRIT, INC.',
#  'CORNER FOOD & LIQUOR INC.',
#  'CRATER FOOD & LIQUOR INC',
#  'CREAM WINE COMPANY LLC',
#  'CREAM WINE COMPANY, LLC',
#  'CREATIVE REALITY ENTERWINED',
#  'CRIB LIQUORS INC',
#  'CRU CAFE & WINE BAR, LIMITED',
#  'D & A FOOD & LIQUOR, INC.',
#  'D & D LIQUOR INC #2',
#  'D & D LIQUORS & FOOD INC',
#  'D & J FOODS & LIQUORS, INC.',
#  'D M H LIQUORS INC.',
#  'D&O FOOD & LIQUOR, INC.',
#  'D. & S. FOOD & LIQUORS, INC.',
#  'DADY MART FOOD & LIQUOR, INC.',
#  'DAILY FOOD & LIQUOR INC.',
#  'DALAL FOOD & LIQUOR INC',
#  'DAMEN LIQUORS, INC.',
#  'DANA LIQUORS, INC.',
#  "DANIAL'S FOOD & LIQUOR CORP",
#  "DANNY'S LIQUORS, INC.",
#  'DAR-RAF FOOD & LIQUOR INC',
#  'DIA FOOD & LIQUOR, INC.',
#  'DIALA GROCERY & LIQUOR, INC.',
#  "DICKENS' LIQUORS INC.",
#  'DISTINCTIVE WINES & SPIRITS, LLC',
#  'DIVERSEY & AUSTIN LIQUOR STORE, INC.',
#  'DIVERSEY & AUSTIN LIQUORS, INC.',
#  'DIVERSEY PRESTIGE LIQUOR AND FOOD CORP.',
#  'DIVERSEY WINE LLC',
#  'DIVISION FOOD & LIQUOR, INC.',
#  'DORCHESTER FOOD & LIQUOR INC',
#  "DOROTHY'S LIQUORS, INC.",
#  'DOUBLE DOOR LIQUORS, INC.',
#  'DOUBLE R FOOD & LIQUOR, INC.',
#  'DYNAMIC FOOD & LIQUOR, INC.',
#  'DYNAMIC LIQUORS INC',
#  'E BELMONTE CUT-RATE LIQUORS',
#  'E R & J FOOD & LIQUOR, INC',
#  'EAGLE FOOD & LIQUOR MARKET INC.',
#  'EAST LAKEVIEW FOOD & LIQUOR INC.',
#  'ECONOMY FOOD & LIQUOR, INC.',
#  'ECONOMY LIQUORS, INC.',
#  "EDDIE'S SUNSHINE FOOD & LIQUOR, INC.",
#  'EDEN LIQUOR & FOOD',
#  'EDENS CONVIENANT LIQUOR STORE INC.',
#  'EL YUNQUE FOOD & LIQUOR INC.',
#  'ELARNID LIQUORS, INC.',
#  'ELM STREET LIQUORS, INC.',
#  'ELSTON & KIMBALL LIQUOR, INC.',
#  'EWING LIQUORS, INC.',
#  'EXPEDITION WINES & SPIRITS, LLC',
#  'EXPRESS FOOD & LIQUOR',
#  'F & R FOOD & LIQUOR INC',
#  'F & R LIQUORS, INC.',
#  'FAME FOOD & LIQUOR INC',
#  'FARMERS MARKET DELI & LIQUORS INC',
#  'FERAS FOOD & LIQUOR, INC.',
#  'FINE FAIR FOOD & LIQUOR, INC.',
#  'FINE FOOD & LIQUOR INC.',
#  'FINE SPIRITS, INC.',
#  'FINE WINE BROKERS, INC.',
#  'FITZGERALD FOOD WINE & SPIRITS, INC.',
#  'FLICKINGER FINE WINE, INC.',
#  'FOOD & LIQUOR EXPRESS, INC',
#  'FOSTER FOOD & LIQUOR, INC.',
#  'FOUR BROTHERS FOOD & LIQUOR INC',
#  'FRANKLIN FOOD & LIQUOR, INC.',
#  'FRANKLIN SUPER FOODS & LIQUORS INC.',
#  'FROTH & SWINE LLC',
#  'FTEX FOODS & LIQUOR INC',
#  'FULLERTON LIQUORS, INC',
#  'G & J GIFTS & LIQUOR INC',
#  'G & N FOOD & LIQUOR INC.',
#  'G & S LIQUORS INC',
#  "GENIE'S DISCOUNT LIQUOR & GROCERY INC.",
#  'GENIN FOOD & LIQUOR, INC.',
#  'GIOVANNI LIQUORS INC',
#  'GLOBE FOOD & LIQUOR INC',
#  'GOLD & SILVER LIQUORS, INC.',
#  'GOLD MEDAL LIQUOR INC',
#  'GOLDEN LEAF FOOD & LIQUOR, INC.',
#  'GRACE LEAVITT LIQUORS CORP.',
#  'GRAIN LIQUORS, LLC',
#  'GRAND FOOD & LIQUOR MART, INC.',
#  'GRAND FOOD & LIQUORS, INC.',
#  'GRAND NOBLE WINE AND SPIRITS CORPORATION',
#  'GREEN ACRES FOOD & LIQUOR',
#  'GREEN FOOD & LIQUOR, INC.',
#  'GREEN GUITAR WINE & SPIRITS INC.',
#  'GREEN OAK FOOD & LIQUOR, INC.',
#  'GROVE LIQUORS, INC.',
#  'H & H CUT RATE LIQUOR STORE, LTD.',
#  'H & K FOODS & LIQUORS INC',
#  'H & L LIQUORS INC.',
#  'H & S FOOD & LIQUORS INC',
#  'H. WEISS LIQUORS, INC.',
#  'HADDAD FOOD & LIQUOR, INC.',
#  'HADDADIN FOOD & LIQUOR INC',
#  'HAHN LIQUORS, INC.',
#  'HANA FOOD & LIQUOR, INC.',
#  'HANBALL FOOD & LIQUOR, INC.',
#  "HANI'S LIQUOR STATION INC",
#  'HAR-HIG LIQUORS, INC.',
#  'HARBEE LIQUORS INC',
#  'HARDEN FOOD & LIQUOR INC',
#  'HAREER FOOD & LIQUOR, INC.',
#  'HART DAVIS HART WINE CO.',
#  'HARVEE LIQUORS INC',
#  'HD LIQUORS, INC.',
#  'HERNANDEZ-CHEHADE GROCERY & LIQUOR STORE, INC.',
#  "HITO'S FOOD & LIQUORS INC",
#  'HML LIQUORS',
#  'HOLIDAY WINES & SPIRITS INC',
#  'HOMAN & CARROLL FOOD/LIQUORS',
#  "HOUSTON'S LIQUOR & FOOD STORE, INC.",
#  'HR LIQUORS, L.L.C.',
#  'HYDE PARK FOOD & LIQUOR, INC.',
#  'I & K FOOD AND LIQUOR, LLC',
#  'I. S. FOOD & LIQUOR INC.',
#  'IBRAHIM FOOD & LIQUOR INC.',
#  'IGNOBLE WINE CO.',
#  'IKES STATE ST FOOD & LIQUORS LLC',
#  'IN FINE SPIRITS, LTD.',
#  'INDEPENDENT SPIRITS INC.',
#  'INTERNATIONAL  LIQUOR & FOOD INC.',
#  'IRVING PARK LIQUORS, INC.',
#  'IRVING/LONG LIQUORS & FDS INC',
#  'ISSA FOOD & LIQUOR INC',
#  'ISSHA LIQUORS INCORPORATED',
#  'ITALIAN WINE BAR - 626 N. STATE, LLC',
#  'J & A LIQUOR INC.',
#  'J & B FOOD AND LIQUORS, INC.',
#  'J & B LIQUORS INC',
#  'J & H FOOD & LIQUOR, INC.',
#  'J & J FOOD & LIQUOR INC',
#  'J & K FOOD & LIQUOR, INC.',
#  'J & L LIQUOR INC',
#  'J & L LIQUORS INC.',
#  'J & T LIQUORS INC',
#  'J & V LIQUORS, INC.',
#  'J & W FOOD & LIQUORS, L.L.C.',
#  'J D R LIQUORS, INC.',
#  'J H LEE FOOD AND LIQUOR INCORPORATED',
#  'J K & S FOOD & LIQUOR, INC.',
#  'J K LIQUORS, INC.',
#  'J R FOOD & LIQUORS INC',
#  'J SON LIQUORS INC',
#  'J. FERAS FOOD & LIQUOR, INC.',
#  "J.M. CHATEAU'S PUB & LIQUORS, INC.",
#  'JAARS WINE AND COMPANY',
#  "JACK'S LIQUOR INC",
#  "JAKE'S LIQUORS INC",
#  'JALARAM FOODS AND LIQUOR, INC.',
#  'JAMAICA FOOD & LIQUOR INC',
#  'JARDAN FOOD & LIQUOR, INC.',
#  'JARVIS LIQUORS INC',
#  "JAY'S FOOD & LIQUOR INC",
#  "JEANINE'S WINE BAR, LLC",
#  'JEFF FOOD & LIQUOR INCORPORATED',
#  'JENNA FOOD & LIQUOR, INC.',
#  "JIM'S FOOD & LIQUOR, INC.",
#  "JIMMY'S WINE & SPIRIT, INC.",
#  "JOE'S LIQUOR STORE, INC.",
#  "JOE'S WINE CELLAR INC.",
#  "JOEL'S WINE & DELI BAR INC",
#  "JOEY'S LIQUOR INC",
#  'JOHAH M WINE',
#  'JOHNNY FOOD & LIQUOR II, INC.',
#  "JOHNNY'S FOOD & LIQUORS, INC.",
#  'K & B FOOD & LIQUOR, INC.',
#  'K & C FOOD & LIQUORS INC.',
#  'K & K FOOD & LIQUOR INC',
#  'K & K LIQUORS INC',
#  'K & R FOOD & LIQUORS',
#  'K N A FOOD & LIQUOR INC.',
#  'KEDZIE GEORGE LIQUORS, INC.',
#  'KEIS FOOD AND LIQUORS INC.',
#  'KENSINGTONS FINE & RARE WINES, INC.',
#  'KENSINGTONS WINE AUCTIONEERS & BROKERS, INC.',
#  'KERFOOT FOOD & LIQUOR, INC.',
#  'KEVIN GROCERY & LIQUOR, LTD.',
#  'KEY FOOD & LIQUOR, INC.',
#  'KEYSTONE WINE AND SPIRITS',
#  "KHALIL'S FOOD & LIQUOR, INC.",
#  'KING CITY FOOD & LIQUOR, INC.',
#  'KING FOOD & LIQUOR, INC.',
#  'KIT KAT MARKET FOOD & LIQUOR INC.',
#  'KODRA LIQUORS, INC.',
#  'KOMAL WINE AND LIQUOR INC.',
#  'L & D FOOD & LIQUORS INC',
#  'L & J FOOD & LIQUOR, INC.',
#  'L & M FOOD & LIQUOR',
#  'L & P LIQUORS INC',
#  "L'FLAMINGO LIQUORS, INC.",
#  'LAKE & WELLS FOOD & LIQUOR',
#  'LAKE EFFECT FINE WINE DIST. CO.',
#  'LAKE FRONT FINE WINE DIST.',
#  'LAMADIA - ART OF PIZZA, LOVE OF WINE, LLC',
#  'LAS AMERICAS FOOD & LIQUOR, INC.',
#  'LATIN GROCERY & LIQUOR, INC',
#  'LAWNDALE FOOD WINE & SPIRITS, INC.',
#  'LAWREL LIQUORS, INC.',
#  'LEADWAY LIQUORS, INC.',
#  'LEGION LIQUORS, INC.',
#  "LEO'S LIQUOR 2 INC.",
#  'LIL VEGAS FOODS & LIQUORS INC',
#  'LIME LIQUORS INC',
#  'LINA FOOD & LIQUOR, INC',
#  'LIQUOR CENTER INC',
#  'LIQUOR DEPOT, INC.',
#  'LIQUOR LICENSE SOLUTIONS, LLC',
#  'LIQUOR ZONE, INC.',
#  'LIQUORS GALORE, LLC',
#  'LIQUORS UNLIMITED INC',
#  "LLOYD'S FOOD LIQUOR INC",
#  'LOCO WINERY TOURS',
#  'LOW-COST FOOD & LIQUOR INC',
#  'LUNT LIQUORS, INC.',
#  'LUX 2 FOOD & LIQUOR, INC.',
#  'M & A FOODS & LIQUOR, INC.',
#  'M & D LIQUOR & FOOD INC',
#  'M & M FOOD & LIQUORS',
#  'M & M GROCERIES & LIQUORS INC',
#  'M & V FOOD & LIQUORS, INC.',
#  'M N A FOOD & LIQUOR',
#  'M W FOOD & LIQUOR INC.',
#  'M&M LIQUOR LLC',
#  'M. F. S. FOOD & LIQUOR INC.',
#  'MADISON FOOD & SPIRITS, INC.,',
#  'MANGO LIQUORS, INC.',
#  'MANHATTAN FOOD & LIQUOR, INC.',
#  'MARCEY STREET WINES, LLC',
#  "MARIE'S LIQUORS INC.",
#  "MARIO'S WINE & SPIRITS, INC",
#  'MARVIN FOOD LIQUOR INC',
#  "MARY'S DISCOUNT FOOD & LIQUOR",
#  'MAS FOOD AND LIQUOR MART, INC.',
#  'MATTHEW P DEWINE',
#  'MATTHEWS FOOD & LIQUORS INC',
#  'MATTICKS WINE & LIQUORS, INC.',
#  'MAURELLE SPIRITS, LTD.',
#  'MAYO FOOD & LIQUOR INC.',
#  'MAZE FOOD & LIQUOR INC',
#  'MCM PUB & LIQUOR, INC.',
#  'MEGA PRESTIGE LIQUORS INC',
#  "MELISSA'S FOOD AND LIQUORS, INC.",
#  'MENARD LIQUORS INC',
#  "MIARA'S BAKERY DELI, WINE & LIQUOR, INC.",
#  'MIDCITY FOOD & LIQUOR INC.',
#  'MILLAN FOOD & LIQUOR, INC',
#  'MOJICA FOOD & LIQUOR INC',
#  'MONARCH CORDAGE & TWINE, INC',
#  'MONTROSE FOOD & LIQUORS, INC.',
#  'MONTROSE LIQUOR MART, INC.',
#  'MONTROSE LIQUORS, INC.',
#  "MORAND'S BUY LOW LIQUOR INC",
#  "MORENO'S DISCOUNT LIQUORS, INC.",
#  'MOROLEON FOOD & LIQUOR, INC.',
#  'MORSE "L" LIQUOR',
#  "MR G'S FOOD & LIQUOR INC",
#  "MULICA'S DELI & LIQUORS INC",
#  'MUSES FOOD & LIQUOR, INC.',
#  'N & M FOOD & LIQUOR, INC.',
#  'N AND A LIQUOR INC.',
#  'N.W. FOOD & LIQUOR, INC.',
#  'NASSAN FOOD & LIQUOR INC',
#  'NAVADA DALLAS LIQUORS INC',
#  'NAWAL FOOD & LIQUOR INC',
#  'NEIGHBORHOOD FOOD & LIQUOR, INC.',
#  'NELSON FOOD & LIQUOR INC.',
#  'NEW KENWOOD FOOD & LIQUOR, INC.',
#  'NEW SAXONY LIQUORS & LOUNGE, LTD.',
#  'NICHE WINE AND SPIRITS, LLC',
#  "NICK'S FOOD & LIQUOR LIMITED",
#  'NICKEL LIQUORS & MINI MART, INC.',
#  'NICKEL LIQUORS INC.',
#  'NIJAR FOOD & LIQUOR, INC.',
#  'NINAT LIQUOR CORPORATION',
#  "NORM AND DEE'S LIQUORS, INC",
#  'NORWOOD PARK WINE & SPIRITS INC.',
#  'NORWOOD PARK. TAP & LIQUORS, INC',
#  "NOWAK'S FARMERS MARKET AND LIQUORS, INC.",
#  'OCHOA GROCERY & LIQUOR, INC',
#  'OHIO FOOD & LIQUOR INC.',
#  'OHIO FOOD & LIQUOR, INC.',
#  "OLA'S LIQUORS INC",
#  'OLD CITY GROCERY & LIQUOR INC',
#  'OLD TOWN SUNDRIES & LIQUORS, INC.',
#  'ONE ELEVEN FOOD & LIQUORS, INC.',
#  'ONE STOP FOOD & LIQUOR INC',
#  'ONE STOP FOOD & LIQUOR STORE, INC.',
#  'ONE STOP FOOD & LIQUORS MART, INC.',
#  'P & B LIQUOR & FOOD INC',
#  'P & I FOOD & LIQUOR INC.',
#  'P & S LIQUOR AND BEER INC.',
#  'P & S LIQUOR INC.',
#  'PACIFIC WINE COMPANY',
#  "PACO'S LIQUORS, INC.",
#  'PAIRED WINE COMPANY CHICAGO, INC.',
#  'PAL FOOD & LIQUOR INC',
#  'PAUL TRACYS LIQUORS INC',
#  'PAY LESS FOOD & LIQUOR, INC.',
#  'PEERLESS LIQUORS INC',
#  'PENUMBRA RESTAURANT AND WINE BAR LLC',
#  'PERFECT FOOD & LIQUORS, INC.',
#  'PERSONAL LIQUORS COMPANY II',
#  'PERSONAL LIQUORS, INC.',
#  'PETE"S FOOD AND LIQUOR INC.',
#  "PHILLIP'S FOOD & LIQUOR INC",
#  'PHOENIX FOOD & LIQUOR, INC',
#  'PLAZA FOOD & LIQUOR INC.',
#  'PM WINE & SPIRITS, INC.',
#  'POLONIA FOOD & LIQUOR, INC.',
#  'POULLMAN FOOD & LIQUOR INC',
#  'PRESTIGE HOYNE LIQUORS, INC.',
#  'PRIME TIME FOOD & LIQUORS 79TH LLC',
#  'PRP WINE INTERNATIONAL, INC.',
#  'PSIN FOOD & LIQUOR INC.',
#  'PTS SPIRITS, INC.',
#  'PUERTO RICO FOOD & LIQUORS, INC.',
#  'QUE SYRAH FINE WINES, LLC',
#  'QUICK STOP FOOD & LIQUOR INC',
#  'QUICK STOP FOOD & LIQUOR MART, INC.',
#  'R & H FOOD & LIQUOR INC',
#  'R & V LIQUORS INC',
#  'R A P LIQUORS INC',
#  'R R R LIQUOR INC',
#  'R. & L. SEARS LIQUORS, INC.',
#  'R.G. FOOD & LIQUOR, INC.',
#  'R.H.A. FOOD & LIQUOR, INC.',
#  'RACINE FOOD & LIQUOR INC',
#  'RADHA KRISHNA LIQUOR, INC.',
#  'RAINBOW FINER FOODS & LIQUOR, INC.',
#  "RAM'S FOOD & LIQUOR INC",
#  'RAMBO FOOD & LIQUOR INC',
#  'RAMMEY FOOD & LIQUOR INC',
#  "RANDY'S LIQUOR LOUNGE INC.",
#  "RAYAN'S RESTAURANT & LIQUORS, INC.",
#  'RED APPLE FOOD & LIQUOR INC',
#  'RED STAR LIQUORS INC',
#  'REDA LIQUORS LTD.',
#  'REYA WINE & SPIRITS INC',
#  "RICH'S DELICATESSEN & LIQUORS, INC",
#  "RITA'S LIQUORS, INC.",
#  'RJ LIQUORS, INC.',
#  'RK LIQUORS INC.',
#  'ROMEO CARRY-OUTS/LIQUORS INC',
#  "ROMIEL'S WINES AND SPIRITS, INC.",
#  'ROOSEVELT FOOD & LIQUOR, INC.',
#  'ROOTSTOCK WINE & BEER BAR, LLC',
#  'ROSELAND FOODS & LIQUOR INC',
#  "ROSSI'S LIQUORS INC",
#  'ROYAL FOOD & LIQUOR, INC.',
#  'RRR RAIDAN LIQUORS, INC.',
#  "RUDY'S FOOD & LIQUORS, INC.",
#  'S & B FOOD & LIQUOR, INC.',
#  'S & J FOOD & LIQUOR INC',
#  'S & K FOOD & LIQUOR, INC.',
#  'S & L FOOD & LIQUORS INC',
#  'S & M LIQUORS, INC.',
#  'S & S LIQUORS, INC.',
#  'S. V. LIQUORS, INC.',
#  'SABANA GRANDE FOOD & LIQUOR INC.',
#  'SAFAH FOOD & LIQUORS INC',
#  'SAGINAW WINE & LIQUORS, INC.',
#  "SAM AND JOE'S LIQUORS, INC.",
#  'SAM LIQUORS INC.',
#  "SAM'S WINES & LIQUORS SL, LLC",
#  'SAN LORENZO FOOD & LIQUOR, INC',
#  'SANAA FOOD & LIQUOR INC',
#  'SANGAMON DISCOUNT LIQUOR',
#  'SANGAMON DISCOUNT LIQUORS INC',
#  'SANTIAGO LIQUOR, INC',
#  "SAR'S FOOD & LIQUORS",
#  'SAVE MORE FOOD & LIQUOR INC',
#  'SAVE WAY FOOD & LIQUOR',
#  'SAVEMORE LIQUORS, INC.',
#  'SD LIQUOR INC.',
#  'SHADEN FOOD & LIQUOR, INC.',
#  'SHAMSAN FOOD & LIQUOR INC',
#  "SHARIF'S FOOD & LIQUORS INC.",
#  'SHEBA FOOD & LIQUOR, INC.',
#  "SHEFFIELD'S BEER & WINE GARDEN, INC.",
#  'SHERIDAN IRVING L LIQUORS INC',
#  'SHERIDAN PARK FOOD & LIQUOR',
#  'SJ FOOD AND LIQUOR, INC.',
#  'SM WINE & SPIRITS INC.',
#  'SOL WINER',
#  'SOLID GOLD FOOD & LIQUOR INC',
#  'SOUTH EAST ALCOHOL AND DRUG ABUSE CENTER',
#  'SOUTH SIDE FOOD & LIQUOR INC.',
#  "SOUTHERN GLAZER'S WINE AND SPIRITS OF ILLINOIS, LLC",
#  'SOUTHERN WINE & SPIRITS OF ILLINOIS',
#  'SPIRITS AND BREW, INC.',
#  'SPIRITS AND GLASS INC.',
#  'SPIRITS BEER & WINE, LLC',
#  'SRD FOOD & LIQUORS, INC.',
#  'STATE GARDEN FOOD & LIQUOR, INC.',
#  'STELLAR WINE COMPANY, LLC',
#  "STEVE'S FOOD & LIQUOR, INC.",
#  'STEWART LIQUORS INC.',
#  'SUN SHINE FOOD & LIQUOR, INC.',
#  'SUNRISE SPIRITS, INC.',
#  'SUNSET LIQUOR & FOOD MART, INC.',
#  'SUPER DEAL FOOD & LIQUOR, INC',
#  'SUPER FOOD & LIQUORS, INC.',
#  'SUPERIOR FOOD & LIQUOR, INC.',
#  'SUPERIOR LIQUOR CORPORATION',
#  'SUTTON LIQUOR CORPORATION',
#  "TABB'S FOOD & LIQUOR, INC.",
#  "TED'S & MIKE'S LIQUORS, INC.",
#  'THE JUICY WINE COMPANY, LLC',
#  'THE WINE CONSORTIUM, LLC',
#  'THE WINE CRIER, LIMITED.',
#  'THE WINE RACK, INC.',
#  'THOMAS FOOD & LIQUORS, INC.',
#  'THOMAS LIQUORS, INC.',
#  'THREE AMIGOS FOOD & LIQUOR INC',
#  'THREE BROTHERS LIQUOR AND LOUNGE INC.',
#  "THREE SON'S FOOD & LIQUOR INC",
#  'THREE STARS FOOD & LIQUOR INC',
#  'THUNDER FOOD & LIQUOR INC.',
#  "TODD'S WINE, LLC",
#  "TONY'S FOOD & LIQUOR",
#  'TOP-LESS LIQUORS, INC.',
#  'TOWN LIQUOR INC',
#  'TRANSFER LIQUORS, INC.',
#  "TRAVELER'S WINE BAR, LLC",
#  "TREVINO'S LIQUORS, INC.",
#  'TRI-ACE LIQUOR COMPANY, INCORPORATED',
#  "TRIER'S  LIQUORS, INC.",
#  'TYROS LIQUORS, INC.',
#  'UMIYA FOOD & LIQUOR, INC.',
#  'UPPER LEFT CORNER WINE COMPANY, LLC',
#  'V & V LIQUORS, INC.',
#  'VALUE FOOD & LIQUOR INC.',
#  'VAS LIQUORS, INC.',
#  'VEGAS FOOD & LIQUOR INC',
#  'VENTOUX  FINE WINE, LLC',
#  "VERN'S LIQUORS INC",
#  'VETERANS FOOD & LIQUOR',
#  'VILLA PARK LIQUORS INC',
#  'VINO FINO LIQUORS, INC.',
#  'VINTAGE WINES LIMITED',
#  "VINTNER'S CELLAR WINERY OF CHICAGO, LLC",
#  'VIP LIQUORS & DELI, INC.',
#  'W & R FOOD & LIQUOR INC',
#  'W K R B FOOD & LIQUOR INC.',
#  'WABASH FOOD & LIQUOR INC',
#  'WALBROOK LIQUORS, INC.',
#  'WALNUT LIQUORS, INC.',
#  'WAREHOUSE LIQUORS, INC.',
#  'WASHINGTON SQUARE LIQUORS INC',
#  'WEST LAKEVIEW LIQUORS, INC',
#  'WEST TOWN WINE &SPIRITS INC.',
#  'WESTERN FINE FOOD & LIQUOR INC.',
#  'WHIPPLE LIQUORS, INC.',
#  'WHITE FRONT LIQUORS, INC.',
#  'WHITESIDE LIQUORS, INC.',
#  'WICKER PARK FOOD & LIQUOR, INC.',
#  'WICKER PARK WINE & SPIRITS, INC.',
#  'WILLIS MINI MART & LIQUOR, INC.',
#  'WINDY CITY RACINE LIQUORS INC.',
#  'WINE 2 FREE CHEF, LLC',
#  'WINE BAR LIMITED',
#  'WINE HUNTRESS, LLC',
#  'WINED.O.C. WINE COMPANY, LLC',
#  'WINERD ENTERTAINMENT, LLC.',
#  'WISLA LIQUORS INC',
#  'WIX, WAX, & WINE INC.',
#  'WORLD WINES INC',
#  'WRIGHTWOOD FOOD & LIQUOR INC.',
#  'YAFAI LIQUORS INC',
#  'YOUR HAPPY PLACE LIQUORS, LLC',
#  'Z & S FOOD & LIQUOR INC',
#  'ZAID CERTIFIED LIQUORS, INC.',
#  'ZEE FOOD & LIQUOR INC'}

# %%
liquor_df.sort_values('LEGAL NAME').head()
# Out:
#                    ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 295795  1584-20150216     2369358             302            1
# 295708  1582-20020516     1229552             302            1
# 295703  1580-20150216     2369361             302            1
# 295678  1580-20020516     1229551             302            1
# 295675  1580-20170216     2501885             302            1
#
#                  LEGAL NAME       DOING BUSINESS AS NAME  \
# 295795  1000 LIQUOR'S, INC.  1000 LIQUORS / BIG CITY TAP
# 295708  1000 LIQUOR'S, INC.  1000 LIQUORS / BIG CITY TAP
# 295703  1000 LIQUOR'S, INC.  1000 LIQUORS / BIG CITY TAP
# 295678  1000 LIQUOR'S, INC.  1000 LIQUORS / BIG CITY TAP
# 295675  1000 LIQUOR'S, INC.  1000 LIQUORS / BIG CITY TAP
#
#                             ADDRESS     CITY STATE ZIP CODE  WARD  PRECINCT  \
# 295795  1000-1012 W BELMONT AVE 1ST  CHICAGO    IL    60657  44.0      39.0
# 295708  1000-1012 W BELMONT AVE 1ST  CHICAGO    IL    60657  44.0      39.0
# 295703  1000-1012 W BELMONT AVE 1ST  CHICAGO    IL    60657  44.0      39.0
# 295678  1000-1012 W BELMONT AVE 1ST  CHICAGO    IL    60657  44.0      39.0
# 295675  1000-1012 W BELMONT AVE 1ST  CHICAGO    IL    60657  44.0      39.0
#
#        WARD PRECINCT  POLICE DISTRICT  LICENSE CODE LICENSE DESCRIPTION  \
# 295795         44-39             19.0          1781             Tobacco
# 295708         44-39             19.0          1471           Late Hour
# 295703         44-39             19.0          1470              Tavern
# 295678         44-39             19.0          1470              Tavern
# 295675         44-39             19.0          1470              Tavern
#
#        BUSINESS ACTIVITY ID  \
# 295795                  763
# 295708                  785
# 295703                  829
# 295678                  829
# 295675                  829
#
#                                         BUSINESS ACTIVITY  LICENSE NUMBER  \
# 295795                             Retail Sale of Tobacco          1584.0
# 295708  Sale of Liquor Until 4am, Monday - Saturday an...          1582.0
# 295703          Tavern - Consumption of Liquor on Premise          1580.0
# 295678          Tavern - Consumption of Liquor on Premise          1580.0
# 295675          Tavern - Consumption of Liquor on Premise          1580.0
#
#        APPLICATION TYPE APPLICATION CREATED DATE  \
# 295795            RENEW                      NaN
# 295708            RENEW               03/27/2002
# 295703            RENEW                      NaN
# 295678            RENEW               03/27/2002
# 295675            RENEW                      NaN
#
#        APPLICATION REQUIREMENTS COMPLETE PAYMENT DATE CONDITIONAL APPROVAL  \
# 295795                        12/15/2014   02/13/2015                    N
# 295708                        05/14/2002   05/14/2002                    N
# 295703                        12/15/2014   02/13/2015                    N
# 295678                        05/14/2002   05/14/2002                    N
# 295675                        12/15/2016   02/10/2017                    N
#
#        LICENSE TERM START DATE LICENSE TERM EXPIRATION DATE  \
# 295795              02/16/2015                   02/15/2017
# 295708              05/16/2002                   11/15/2002
# 295703              02/16/2015                   02/15/2017
# 295678              05/16/2002                   11/15/2002
# 295675              02/16/2017                   02/15/2019
#
#        LICENSE APPROVED FOR ISSUANCE DATE ISSUED LICENSE STATUS  \
# 295795                    02/13/2015  02/13/2015            AAI
# 295708                    05/14/2002  11/14/2002            AAI
# 295703                    02/13/2015  02/13/2015            AAI
# 295678                    05/14/2002  05/15/2002            AAI
# 295675                    02/10/2017  02/10/2017            AAI
#
#        LICENSE STATUS CHANGE DATE   SSA  LATITUDE  LONGITUDE  \
# 295795                        NaN  17.0  41.94002 -87.654172
# 295708                        NaN  17.0  41.94002 -87.654172
# 295703                        NaN  17.0  41.94002 -87.654172
# 295678                        NaN  17.0  41.94002 -87.654172
# 295675                        NaN  17.0  41.94002 -87.654172
#
#                                         LOCATION
# 295795  (41.940020360226804, -87.65417210636889)
# 295708  (41.940020360226804, -87.65417210636889)
# 295703  (41.940020360226804, -87.65417210636889)
# 295678  (41.940020360226804, -87.65417210636889)
# 295675  (41.940020360226804, -87.65417210636889)

# %%
# Checking for license statuses that were not issued
len(liquor_df[liquor_df['LICENSE STATUS'] != 'AAI'])
# Out:
# 512

# %% [markdown]
# There are several instances of businesses that were not issued a license, but I will include them as it is possible that they were operating at some point during the period from 2001 to 2018.  As liquor stores have to continuously apply for licenses, there are duplicates which will need to be dropped.

# %%
# Grabbing a few columns
liquor_df = liquor_df[['LEGAL NAME', 'LATITUDE', 'LONGITUDE', 'ADDRESS']]

# %%
len(liquor_df)
# Out:
# 13552

# %%
# Dropping duplicate items
liquor_df.drop_duplicates(inplace=True)

# Resetting the index for liquor_df before moving on
liquor_df = liquor_df.reset_index(drop = True)

# %%
len(liquor_df)
# Out:
# 709

# %%
# Checking for any bad lat/long points
plt.scatter(liquor_df['LONGITUDE'], liquor_df['LATITUDE'])

# %%
# Checking for null values in lat/long
len(liquor_df['LATITUDE']) - len(liquor_df['LATITUDE'].dropna()), len(liquor_df['LONGITUDE']) - len(liquor_df['LONGITUDE'].dropna())
# Out:
# (4, 4)

# %%
liquor_df[(liquor_df['LATITUDE'].isnull())]
# Out:
#                         LEGAL NAME  LATITUDE  LONGITUDE  \
# 284            THE WINE RACK, INC.       NaN        NaN
# 625          VINTAGE WINES LIMITED       NaN        NaN
# 654  WASHINGTON SQUARE LIQUORS INC       NaN        NaN
# 660      DOUBLE DOOR LIQUORS, INC.       NaN        NaN
#
#                                        ADDRESS
# 284       1340 W MADISON ST BSMT, 1ST FL, MEZZ
# 625                        2700  RIVER RD  301
# 654                       420 N CLARK ST  1 ST
# 660  1572 N MILWAUKEE AVE BSMT, 1ST, MEZZANINE

# %% [markdown]
# There are 4 liquor stores that are missing locations.  Using the website https://www.latlong.net/convert-address-to-lat-long.html I can convert the address to latitude/longitude.

# %%
# Adding missing lat/long
liquor_df.loc[284, 'LATITUDE'] = 41.881660
liquor_df.loc[284, 'LONGITUDE'] = -87.661247

liquor_df.loc[654, 'LATITUDE'] = 41.889900
liquor_df.loc[654, 'LONGITUDE'] = -87.631360

liquor_df.loc[660, 'LATITUDE'] = 41.909918
liquor_df.loc[660, 'LONGITUDE'] = -87.677131

# %% [markdown]
# Vintage Wines Limited is located outside of the Chicago Area so I will delete it.

# %%
# Removing bad store
liquor_df = liquor_df.drop(625)

# %%
# Resetting the index for liquor_df 
liquor_df = liquor_df.reset_index(drop = True)

# %%
# Checking for any bad lat/long points
plt.scatter(liquor_df['LONGITUDE'], liquor_df['LATITUDE'])

# %%
# Saving all liquor stores to csv
liquor_df.to_csv('Liquor.csv', index = False)

# %% [markdown]
# ## Distance from Closest Liquor Store

# %%
# reading crime csv
crime_df = pd.read_csv('Crimes_2001_into_2018_Cleaned.csv')

# %%
crime_df.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13

# %%
# Creating a temporary dataframe with non-null entries of latitude and longitude
crime_df_notnull = crime_df[pd.notnull(crime_df['Latitude'])]

# Resetting the index for crime_df_notnull before moving on
crime_df_notnull = crime_df_notnull.reset_index(drop = True)

# %%
liquor_df.head()
# Out:
#                       LEGAL NAME   LATITUDE  LONGITUDE  \
# 0     FLICKINGER FINE WINE, INC.  41.859977 -87.637946
# 1          DANNY'S LIQUORS, INC.  41.935989 -87.718982
# 2      ALTGELD GARDEN LIQUOR INC  41.656753 -87.597599
# 3          ASHLAND LIQUORS, INC.  41.896199 -87.666257
# 4  GREEN OAK FOOD & LIQUOR, INC.  41.900361 -87.643236
#
#                          ADDRESS
# 0  1600 S STEWART AVE 5TH & BSMT
# 1       3018 N MILWAUKEE AVE 1ST
# 2          13118 S ELLIS AVE 1ST
# 3         1532 W CHICAGO AVE 1ST
# 4              956 N LARRABEE ST

# %%
# Converting the liquor store coordinates to radians and zipping them together 
liquor = list(zip(np.deg2rad(liquor_df['LATITUDE']), np.deg2rad(liquor_df['LONGITUDE'])))

# The BallTree is created using the liquor store coordinates
tree = BallTree(liquor, metric = DistanceMetric.get_metric('haversine'))

# Converting the crime coordinates to radians and zipping them together
crime = list(zip(np.deg2rad(crime_df_notnull['Latitude']), np.deg2rad(crime_df_notnull['Longitude'])))

# %%
# Finding the closest liquor store for each crime - split into 2 to speed up
dists, ind = tree.query(crime[0:3333088], k=1) # returns distance and index of nearest liquor store
dists2, ind2 = tree.query(crime[3333088:], k=1)

# %%
# Combining dists and ind
dists_all = np.vstack([dists, dists2])
ind_all = np.vstack([ind, ind2])

# Extracting the nearest liquor store name from ind_all
index_liq = list(ind_all[:,0])
name_liq = list(liquor_df['LEGAL NAME'][index_liq])

# Extracting the distance from the nearest liquor store from dists_all and converting from radians to km
distances_liq = list((dists_all[:,0] * 6371).round(2))

# %%
len(distances_liq) - len(crime_df_notnull)
# Out:
# 0

# %%
# Creating new columns
crime_df_notnull['Closest Liquor Store'] = name_liq
crime_df_notnull['Distance from Closest Liquor Store (km)'] = distances_liq

# %%
crime_df_notnull.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13
#
#                  Closest Liquor Store  Distance from Closest Liquor Store (km)
# 0              MAZE FOOD & LIQUOR INC                                     0.10
# 1       BIG SAM'S FOOD & LIQUOR, INC.                                     0.53
# 2  ONE STOP FOOD & LIQUOR STORE, INC.                                     0.37
# 3      51ST EXPRESS FOOD & LIQUOR INC                                     0.15
# 4           NIJAR FOOD & LIQUOR, INC.                                     0.70

# %%
crime_df_notnull.columns
# Out:
# Index(['ID', 'Date', 'Year', 'Block', 'Primary Type', 'Location Description',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community', 'X Coordinate',
#        'Y Coordinate', 'Latitude', 'Longitude', 'Month', 'Season',
#        'Quarter of Year', 'Day of the Week', 'Day Type', 'Time of Day', 'Day',
#        'Hour', 'Third of Month', 'Street', 'Holiday', 'Is Holiday',
#        'Closest Train Stop', 'Closest Train Line',
#        'Distance from Closest Train Stop (km)', 'Closest Bus Stop',
#        'Distance from Closest Bus Stop (km)', 'Closest Liquor Store',
#        'Distance from Closest Liquor Store (km)'],
#       dtype='object')

# %%
# Joining crime_df_notnull with crime_df
crime_df2 = pd.merge(crime_df, crime_df_notnull[['ID', 'Closest Liquor Store',
       'Distance from Closest Liquor Store (km)']], left_on = 'ID', right_on = 'ID', how = 'left')

# %%
crime_df2.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13
#
#                  Closest Liquor Store  Distance from Closest Liquor Store (km)
# 0              MAZE FOOD & LIQUOR INC                                     0.10
# 1       BIG SAM'S FOOD & LIQUOR, INC.                                     0.53
# 2  ONE STOP FOOD & LIQUOR STORE, INC.                                     0.37
# 3      51ST EXPRESS FOOD & LIQUOR INC                                     0.15
# 4           NIJAR FOOD & LIQUOR, INC.                                     0.70

# %%
# Saving crime_df2 to csv
crime_df2.to_csv('Crimes_2001_into_2018_Cleaned.csv', index = False)
