# %% [markdown]
# Data Source: https://data.cityofchicago.org/Public-Safety/Chicago-Police-Department-Illinois-Uniform-Crime-R/c7ck-438e

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from math import radians, sin, cos, sqrt, atan2
from sklearn.neighbors import KDTree, BallTree, DistanceMetric
import matplotlib.pyplot as plt
# %matplotlib inline 
pd.options.display.max_columns = 1000

# %%
# Reading in the crime data csv file and converting to a dataframe
crime_df = pd.read_csv('Crimes_2001_into_2018_Cleaned.csv')

# %%
crime_df.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13
#
#                  Closest Liquor Store  Distance from Closest Liquor Store (km)
# 0              MAZE FOOD & LIQUOR INC                                     0.10
# 1       BIG SAM'S FOOD & LIQUOR, INC.                                     0.53
# 2  ONE STOP FOOD & LIQUOR STORE, INC.                                     0.37
# 3      51ST EXPRESS FOOD & LIQUOR INC                                     0.15
# 4           NIJAR FOOD & LIQUOR, INC.                                     0.70

# %% [markdown]
# ## Distance from Chicago

# %%
# Defining function
def haversine(lat1, lon1, lat2, lon2):
    """Calculates the distance between two lat/lon positions"""
    R = 6371 # mean Earth's radius in km
    lat1, lon1, lat2, lon2 = map(np.deg2rad, [lat1, lon1, lat2, lon2]) # converting lat/lon from degrees to radians
    
    phi_1 = lat1
    phi_2 = lat2
    
    delta_phi = lat2 - lat1
    delta_lambda = lon2 - lon1
    
    a = np.sin(delta_phi/2.0)**2 + np.cos(phi_1) * np.cos(phi_2) * np.sin(delta_lambda/2.0)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return round((R * c), 2) # returns the distance in km rounded to the nearest hundredth

# %%
# Calculating the distance of each crime from Chicago
# The coordinates used for Chicago are from https://www.latlong.net/place/chicago-il-usa-1855.html
chicago_lat = 41.881832
chicago_lon = -87.623177

crime_df['Distance from Chicago (km)'] = crime_df.apply(lambda row: haversine(chicago_lat, chicago_lon, row['Latitude'], row['Longitude']), axis = 1)

# %%
crime_df.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13
#
#                  Closest Liquor Store  \
# 0              MAZE FOOD & LIQUOR INC
# 1       BIG SAM'S FOOD & LIQUOR, INC.
# 2  ONE STOP FOOD & LIQUOR STORE, INC.
# 3      51ST EXPRESS FOOD & LIQUOR INC
# 4           NIJAR FOOD & LIQUOR, INC.
#
#    Distance from Closest Liquor Store (km)  Distance from Chicago (km)
# 0                                     0.10                       10.09
# 1                                     0.53                       12.56
# 2                                     0.37                        7.87
# 3                                     0.15                        9.01
# 4                                     0.70                        9.96

# %% [markdown]
# ## Distance from Closest Police Station

# %%
# Reading in the police station csv file and converting to a dataframe
police_df = pd.read_csv('Police_Stations.csv')

# %%
police_df
# Out:
#         DISTRICT                   ADDRESS     CITY STATE    ZIP  \
# 0              1           1718 S State St  Chicago    IL  60616
# 1              2      5101 S Wentworth Ave  Chicago    IL  60609
# 2              3  7040 S Cottage Grove Ave  Chicago    IL  60637
# 3              4           2255 E 103rd St  Chicago    IL  60617
# 4              5            727 E 111th St  Chicago    IL  60628
# 5              6         7808 S Halsted St  Chicago    IL  60620
# 6              7            1438 W 63rd St  Chicago    IL  60636
# 7              8            3420 W 63rd St  Chicago    IL  60629
# 8              9         3120 S Halsted St  Chicago    IL  60608
# 9             10          3315 W Ogden Ave  Chicago    IL  60623
# 10            11        3151 W Harrison St  Chicago    IL  60612
# 11            12  1412 S Blue Island Ave\n  Chicago    IL  60608
# 12            14     2150 N California Ave  Chicago    IL  60647
# 13            15         5701 W Madison St  Chicago    IL  60644
# 14            16      5151 N Milwaukee Ave  Chicago    IL  60630
# 15            17         4650 N Pulaski Rd  Chicago    IL  60630
# 16            18        1160 N Larrabee St  Chicago    IL  60610
# 17            19          850 W Addison St  Chicago    IL  60613
# 18            20        5400 N Lincoln Ave  Chicago    IL  60625
# 19            22       1900 W Monterey Ave  Chicago    IL  60643
# 20            24           6464 N Clark St  Chicago    IL  60626
# 21            25          5555 W Grand Ave  Chicago    IL  60639
# 22  Headquarters       3510 S Michigan Ave  Chicago    IL  60653
#
#                                               WEBSITE  \
# 0   http://home.chicagopolice.org/community/distri...
# 1   http://home.chicagopolice.org/community/distri...
# 2   http://home.chicagopolice.org/community/distri...
# 3   http://home.chicagopolice.org/community/distri...
# 4   http://home.chicagopolice.org/community/distri...
# 5   http://home.chicagopolice.org/community/distri...
# 6   http://home.chicagopolice.org/community/distri...
# 7   http://home.chicagopolice.org/community/distri...
# 8   http://home.chicagopolice.org/community/distri...
# 9   http://home.chicagopolice.org/community/distri...
# 10  http://home.chicagopolice.org/community/distri...
# 11  http://home.chicagopolice.org/community/distri...
# 12  http://home.chicagopolice.org/community/distri...
# 13  http://home.chicagopolice.org/community/distri...
# 14  http://home.chicagopolice.org/community/distri...
# 15  http://home.chicagopolice.org/community/distri...
# 16  http://home.chicagopolice.org/community/distri...
# 17  http://home.chicagopolice.org/community/distri...
# 18  http://home.chicagopolice.org/community/distri...
# 19  http://home.chicagopolice.org/community/distri...
# 20  http://home.chicagopolice.org/community/distri...
# 21  http://home.chicagopolice.org/community/distri...
# 22                      http://home.chicagopolice.org
#
#                            LOCATION
# 0    (41.8583725929, -87.627356171)
# 1   (41.8018110912, -87.6305601801)
# 2   (41.7664308925, -87.6057478606)
# 3   (41.7079332906, -87.5683491228)
# 4   (41.6927233639, -87.6045058667)
# 5   (41.7521368378, -87.6442289066)
# 6   (41.7796315359, -87.6608870173)
# 7    (41.778987189, -87.7088638153)
# 8   (41.8373944311, -87.6464077068)
# 9    (41.8566845327, -87.708381958)
# 10   (41.8735822883, -87.705488126)
# 11  (41.8629766244, -87.6569725149)
# 12  (41.9211033246, -87.6974518223)
# 13   (41.8800834614, -87.768199889)
# 14  (41.9740944511, -87.7661488432)
# 15   (41.9660534171, -87.728114561)
# 16  (41.9032416531, -87.6433521393)
# 17   (41.9474004564, -87.651512018)
# 18  (41.9795495131, -87.6928445094)
# 19  (41.6914347795, -87.6685203937)
# 20  (41.9997634842, -87.6713242922)
# 21   (41.9186088912, -87.765574479)
# 22  (41.8307016873, -87.6233953459)

# %%
# Excluding the police headquarters
police_df = police_df.drop(police_df.index[[22]])

# %%
# Splitting the latitude and longitude from 'LOCATION'
latitude = []
longitude = []
for item in police_df['LOCATION']: 
    lat, lon = item.strip('()').split(',')
    latitude.append(float(lat))
    longitude.append(float(lon))

# Creating columns for latitude and longitude
police_df['LATITUDE'] = latitude
police_df['LONGITUDE'] = longitude

# %%
police_df.head()
# Out:
#   DISTRICT                   ADDRESS     CITY STATE    ZIP  \
# 0        1           1718 S State St  Chicago    IL  60616
# 1        2      5101 S Wentworth Ave  Chicago    IL  60609
# 2        3  7040 S Cottage Grove Ave  Chicago    IL  60637
# 3        4           2255 E 103rd St  Chicago    IL  60617
# 4        5            727 E 111th St  Chicago    IL  60628
#
#                                              WEBSITE  \
# 0  http://home.chicagopolice.org/community/distri...
# 1  http://home.chicagopolice.org/community/distri...
# 2  http://home.chicagopolice.org/community/distri...
# 3  http://home.chicagopolice.org/community/distri...
# 4  http://home.chicagopolice.org/community/distri...
#
#                           LOCATION   LATITUDE  LONGITUDE
# 0   (41.8583725929, -87.627356171)  41.858373 -87.627356
# 1  (41.8018110912, -87.6305601801)  41.801811 -87.630560
# 2  (41.7664308925, -87.6057478606)  41.766431 -87.605748
# 3  (41.7079332906, -87.5683491228)  41.707933 -87.568349
# 4  (41.6927233639, -87.6045058667)  41.692723 -87.604506

# %%
# Creating a temporary dataframe with non-null entries of latitude and longitude
crime_df_notnull = crime_df[pd.notnull(crime_df['Latitude'])]

# Resetting the index for crime_df_notnull before moving on
crime_df_notnull = crime_df_notnull.reset_index(drop = True)

# %%
# Converting the police station coordinates to radians and zipping them together 
police = list(zip(np.deg2rad(police_df['LATITUDE']), np.deg2rad(police_df['LONGITUDE'])))

# The BallTree is created using the police coordinates
tree = BallTree(police, metric = DistanceMetric.get_metric('haversine'))

# Converting the crime coordinates to radians and zipping them together
crime = list(zip(np.deg2rad(crime_df_notnull['Latitude']), np.deg2rad(crime_df_notnull['Longitude'])))

# %%
# Finding the closest police station for each crime
dists, ind = tree.query(crime, k=1) # returns distance and index of nearest police station

# Extracting the nearest police station (district) from ind
index = list(ind[:,0])
stations = list(police_df['DISTRICT'][index])

# Extracting the distance from the nearest police station from dists and converting from radians to km
distances = list((dists[:,0] * 6371).round(2))

# %%
# Creating new columns
crime_df_notnull['Closest Police Station (District)'] = stations
crime_df_notnull['Distance from Closest Police Station (km)'] = distances

# %%
crime_df_notnull.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13
#
#                  Closest Liquor Store  \
# 0              MAZE FOOD & LIQUOR INC
# 1       BIG SAM'S FOOD & LIQUOR, INC.
# 2  ONE STOP FOOD & LIQUOR STORE, INC.
# 3      51ST EXPRESS FOOD & LIQUOR INC
# 4           NIJAR FOOD & LIQUOR, INC.
#
#    Distance from Closest Liquor Store (km)  Distance from Chicago (km)  \
# 0                                     0.10                       10.09
# 1                                     0.53                       12.56
# 2                                     0.37                        7.87
# 3                                     0.15                        9.01
# 4                                     0.70                        9.96
#
#   Closest Police Station (District)  Distance from Closest Police Station (km)
# 0                                15                                       2.34
# 1                                 7                                       0.79
# 2                                 2                                       3.11
# 3                                 2                                       0.67
# 4                                15                                       2.07

# %%
crime_df.columns
# Out:
# Index(['ID', 'Date', 'Year', 'Block', 'Primary Type', 'Location Description',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community', 'X Coordinate',
#        'Y Coordinate', 'Latitude', 'Longitude', 'Month', 'Season',
#        'Quarter of Year', 'Day of the Week', 'Day Type', 'Time of Day', 'Day',
#        'Hour', 'Third of Month', 'Street', 'Holiday', 'Is Holiday',
#        'Closest Train Stop', 'Closest Train Line',
#        'Distance from Closest Train Stop (km)', 'Closest Bus Stop',
#        'Distance from Closest Bus Stop (km)', 'Closest Liquor Store',
#        'Distance from Closest Liquor Store (km)',
#        'Distance from Chicago (km)'],
#       dtype='object')

# %%
# Joining crime_df_notnull with crime_df
crime_df2 = pd.merge(crime_df, crime_df_notnull[['ID', 'Closest Police Station (District)', 'Distance from Closest Police Station (km)']], left_on = 'ID', right_on = 'ID', how = 'left')

# %%
crime_df2.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13
#
#                  Closest Liquor Store  \
# 0              MAZE FOOD & LIQUOR INC
# 1       BIG SAM'S FOOD & LIQUOR, INC.
# 2  ONE STOP FOOD & LIQUOR STORE, INC.
# 3      51ST EXPRESS FOOD & LIQUOR INC
# 4           NIJAR FOOD & LIQUOR, INC.
#
#    Distance from Closest Liquor Store (km)  Distance from Chicago (km)  \
# 0                                     0.10                       10.09
# 1                                     0.53                       12.56
# 2                                     0.37                        7.87
# 3                                     0.15                        9.01
# 4                                     0.70                        9.96
#
#   Closest Police Station (District)  Distance from Closest Police Station (km)
# 0                                15                                       2.34
# 1                                 7                                       0.79
# 2                                 2                                       3.11
# 3                                 2                                       0.67
# 4                                15                                       2.07

# %%
# Saving clean crime_df to csv
crime_df2.to_csv('Crimes_2001_into_2018_Cleaned.csv', index = False)
