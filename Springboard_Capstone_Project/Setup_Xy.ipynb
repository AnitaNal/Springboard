# %%
import pandas as pd
import numpy as np
from sklearn.utils.validation import column_or_1d
import seaborn as sns
from tqdm import tqdm
from time import time

import matplotlib.pyplot as plt
# %matplotlib inline 
pd.options.display.max_columns = 1000

# %%
# Reading in the crime data csv file and converting to a dataframe
crime_df = pd.read_csv('../Crimes_2001_into_2018_Cleaned.csv')

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6726512 entries, 0 to 6726511
# Data columns (total 37 columns):
# ID                                           int64
# Date                                         object
# Year                                         int64
# Block                                        object
# Primary Type                                 object
# Location Description                         object
# Domestic                                     bool
# Beat                                         int64
# District                                     float64
# Ward                                         float64
# Community                                    float64
# X Coordinate                                 float64
# Y Coordinate                                 float64
# Latitude                                     float64
# Longitude                                    float64
# Month                                        int64
# Season                                       object
# Quarter of Year                              object
# Day of the Week                              object
# Day Type                                     object
# Time of Day                                  object
# Day                                          int64
# Hour                                         int64
# Third of Month                               object
# Street                                       object
# Holiday                                      object
# Is Holiday                                   bool
# Distance from Chicago (km)                   float64
# Closest Police Station (District)            float64
# Distance from Closest Police Station (km)    float64
# Closest Train Stop                           object
# Closest Train Line                           object
# Distance from Closest Train Stop (km)        float64
# Closest Bus Stop                             object
# Distance from Closest Bus Stop (km)          float64
# Closest Liquor Store                         object
# Distance from Closest Liquor Store (km)      float64
# dtypes: bool(2), float64(13), int64(6), object(16)
# memory usage: 1.8+ GB

# %%
crime_df.head()
# Out:
#         ID                 Date  Year                  Block Primary Type  \
# 0      757  2001-04-12 21:32:00  2001      056XX S NORMAL AV     HOMICIDE
# 1      808  2001-05-06 01:30:00  2001          020XX W 55 ST     HOMICIDE
# 2  8389450  2008-04-15 15:00:00  2008  081XX W CATHERINE AVE        THEFT
# 3      937  2001-07-15 00:34:00  2001     030XX S HARDING ST     HOMICIDE
# 4      983  2001-07-29 10:15:00  2001     011XX N LASALLE ST     HOMICIDE
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False   711       7.0  20.0       68.0
# 1                 AUTO     False   915       9.0   NaN        NaN
# 2            RESIDENCE      True  1611      16.0  41.0       10.0
# 3               STREET     False  1031      10.0   NaN        NaN
# 4                ALLEY     False  1824      18.0   NaN        NaN
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1173875.0     1867697.0  41.792370 -87.637960      4  SPRING
# 1           NaN           NaN        NaN        NaN      5  SPRING
# 2     1120943.0     1934726.0  41.977319 -87.830619      4  SPRING
# 3           NaN           NaN        NaN        NaN      7  SUMMER
# 4           NaN           NaN        NaN        NaN      7  SUMMER
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q2        THURSDAY  WEEKDAY     EVENING   12    21
# 1              Q2          SUNDAY  WEEKEND   OVERNIGHT    6     1
# 2              Q2         TUESDAY  WEEKDAY   AFTERNOON   15    15
# 3              Q3          SUNDAY  WEEKEND   OVERNIGHT   15     0
# 4              Q3          SUNDAY  WEEKEND     MORNING   29    10
#
#   Third of Month           Street     Holiday  Is Holiday  \
# 0             T2      S NORMAL AV  No Holiday       False
# 1             T1          W 55 ST  No Holiday       False
# 2             T2  W CATHERINE AVE  No Holiday       False
# 3             T2     S HARDING ST  No Holiday       False
# 4             T3     N LASALLE ST  No Holiday       False
#
#    Distance from Chicago (km)  Closest Police Station (District)  \
# 0                       10.02                                2.0
# 1                         NaN                                NaN
# 2                       20.18                               16.0
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#    Distance from Closest Police Station (km) Closest Train Stop  \
# 0                                       1.22           Garfield
# 1                                        NaN                NaN
# 2                                       5.34         Cumberland
# 3                                        NaN                NaN
# 4                                        NaN                NaN
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0           Red Line                                   0.66
# 1                NaN                                    NaN
# 2          Blue Line                                   0.98
# 3                NaN                                    NaN
# 4                NaN                                    NaN
#
#          Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 0       Garfield & Normal                                 0.19
# 1                     NaN                                  NaN
# 2  Cumberland & Catherine                                 0.49
# 3                     NaN                                  NaN
# 4                     NaN                                  NaN
#
#           Closest Liquor Store  Distance from Closest Liquor Store (km)
# 0    ATSHAN FOOD & LIQUOR INC.                                     0.24
# 1                          NaN                                      NaN
# 2  MARIO'S WINE & SPIRITS, INC                                     0.51
# 3                          NaN                                      NaN
# 4                          NaN                                      NaN

# %%
# Getting counts of each primary type of crime
counts = crime_df['Primary Type'].value_counts()
counts
# Out:
# THEFT                                1412991
# BATTERY                              1228590
# CRIMINAL DAMAGE                       769380
# NARCOTICS                             709729
# OTHER OFFENSE                         417205
# ASSAULT                               416975
# BURGLARY                              387093
# MOTOR VEHICLE THEFT                   313488
# DECEPTIVE PRACTICE                    260930
# ROBBERY                               254886
# CRIMINAL TRESPASS                     192878
# WEAPONS VIOLATION                      70274
# PROSTITUTION                           68257
# PUBLIC PEACE VIOLATION                 47671
# OFFENSE INVOLVING CHILDREN             45138
# CRIM SEXUAL ASSAULT                    26932
# SEX OFFENSE                            24971
# INTERFERENCE WITH PUBLIC OFFICER       15055
# GAMBLING                               14410
# LIQUOR LAW VIOLATION                   14036
# ARSON                                  11122
# HOMICIDE                                9170
# KIDNAPPING                              6648
# INTIMIDATION                            3914
# STALKING                                3357
# OBSCENITY                                576
# CONCEALED CARRY LICENSE VIOLATION        272
# NON-CRIMINAL                             209
# PUBLIC INDECENCY                         161
# OTHER NARCOTIC VIOLATION                 123
# HUMAN TRAFFICKING                         47
# RITUALISM                                 23
# DOMESTIC VIOLENCE                          1
# Name: Primary Type, dtype: int64

# %%
# Creating a dataframe of the primary type counts
df = counts.rename_axis('Primary Type').reset_index(name='counts')
df
# Out:
#                          Primary Type   counts
# 0                               THEFT  1412991
# 1                             BATTERY  1228590
# 2                     CRIMINAL DAMAGE   769380
# 3                           NARCOTICS   709729
# 4                       OTHER OFFENSE   417205
# 5                             ASSAULT   416975
# 6                            BURGLARY   387093
# 7                 MOTOR VEHICLE THEFT   313488
# 8                  DECEPTIVE PRACTICE   260930
# 9                             ROBBERY   254886
# 10                  CRIMINAL TRESPASS   192878
# 11                  WEAPONS VIOLATION    70274
# 12                       PROSTITUTION    68257
# 13             PUBLIC PEACE VIOLATION    47671
# 14         OFFENSE INVOLVING CHILDREN    45138
# 15                CRIM SEXUAL ASSAULT    26932
# 16                        SEX OFFENSE    24971
# 17   INTERFERENCE WITH PUBLIC OFFICER    15055
# 18                           GAMBLING    14410
# 19               LIQUOR LAW VIOLATION    14036
# 20                              ARSON    11122
# 21                           HOMICIDE     9170
# 22                         KIDNAPPING     6648
# 23                       INTIMIDATION     3914
# 24                           STALKING     3357
# 25                          OBSCENITY      576
# 26  CONCEALED CARRY LICENSE VIOLATION      272
# 27                       NON-CRIMINAL      209
# 28                   PUBLIC INDECENCY      161
# 29           OTHER NARCOTIC VIOLATION      123
# 30                  HUMAN TRAFFICKING       47
# 31                          RITUALISM       23
# 32                  DOMESTIC VIOLENCE        1

# %%
# Plotting the number of crimes by primary type
df.plot.bar(x = 'Primary Type', legend = None, figsize = (10,10))

# %%
# Only using data for the top 11 primary types of crimes
crime_df = crime_df[[each in ['THEFT', 'BATTERY', 'CRIMINAL DAMAGE', 'NARCOTICS', 'ASSAULT', 'OTHER OFFENSE', 'BURGLARY', 'MOTOR VEHICLE THEFT', 'DECEPTIVE PRACTICE', 'ROBBERY', 'CRIMINAL TRESPASS'] for each in crime_df['Primary Type']]]

# %%
len(crime_df)
# Out:
# 6364145

# %%
# Deleting unneeded columns
del crime_df['Date']
del crime_df['Block']
del crime_df['Street']

# %%
# Dropping null values
crime_df = crime_df.dropna()
len(crime_df)
# Out:
# 6357103

# %%
# Adding columns
crime_df['Square Root of Distance from Closest Police Station (km)'] = np.sqrt(crime_df['Distance from Closest Police Station (km)'])
crime_df['Square Root of Distance from Closest Bus Stop (km)'] = np.sqrt(crime_df['Distance from Closest Bus Stop (km)'])
crime_df['Square Root of Distance from Closest Liquor Store (km)'] = np.sqrt(crime_df['Distance from Closest Liquor Store (km)'])

# %%
# Getting sample df
crime_sample_3mil = crime_df.sample(3000000, random_state=23)

# %% [markdown]
# ## SETTING X AND Y

# %%
crime_df.head()
# Out:
#         ID  Year Primary Type Location Description  Domestic  Beat  District  \
# 2  8389450  2008        THEFT            RESIDENCE      True  1611      16.0
# 5  1920659  2002      BATTERY   GROCERY FOOD STORE     False   512       5.0
# 7  1920699  2002      BATTERY            RESIDENCE     False   513       5.0
# 8  1921127  2002      ASSAULT            RESIDENCE      True   512       5.0
# 9  1921304  2002        THEFT   GROCERY FOOD STORE     False  2212      22.0
#
#    Ward  Community  X Coordinate  Y Coordinate   Latitude  Longitude  Month  \
# 2  41.0       10.0     1120943.0     1934726.0  41.977319 -87.830619      4
# 5   9.0       49.0     1180290.0     1836704.0  41.707177 -87.615386      1
# 7  34.0       49.0     1176352.0     1831284.0  41.692393 -87.629969      1
# 8  34.0       49.0     1176290.0     1834271.0  41.700591 -87.630107      1
# 9  19.0       75.0     1162749.0     1830916.0  41.691677 -87.679782      1
#
#    Season Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 2  SPRING              Q2         TUESDAY  WEEKDAY   AFTERNOON   15    15
# 5  WINTER              Q1         TUESDAY  WEEKDAY   AFTERNOON    1    15
# 7  WINTER              Q1       WEDNESDAY  WEEKDAY     MORNING    2    10
# 8  WINTER              Q1       WEDNESDAY  WEEKDAY   AFTERNOON    2    15
# 9  WINTER              Q1       WEDNESDAY  WEEKDAY     MORNING    2    10
#
#   Third of Month         Holiday  Is Holiday  Distance from Chicago (km)  \
# 2             T2      No Holiday       False                       20.18
# 5             T1  New Year's Day        True                       19.43
# 7             T1      No Holiday       False                       21.07
# 8             T1      No Holiday       False                       20.16
# 9             T1      No Holiday       False                       21.66
#
#    Closest Police Station (District)  \
# 2                               16.0
# 5                                5.0
# 7                                5.0
# 8                                5.0
# 9                               22.0
#
#    Distance from Closest Police Station (km) Closest Train Stop  \
# 2                                       5.34         Cumberland
# 5                                       1.84      95th/Dan Ryan
# 7                                       2.11      95th/Dan Ryan
# 8                                       2.30      95th/Dan Ryan
# 9                                       0.94      95th/Dan Ryan
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 2          Blue Line                                   0.98
# 5           Red Line                                   1.85
# 7           Red Line                                   3.37
# 8           Red Line                                   2.47
# 9           Red Line                                   5.73
#
#            Closest Bus Stop  Distance from Closest Bus Stop (km)  \
# 2    Cumberland & Catherine                                 0.49
# 5    103rd Street & Calumet                                 0.03
# 7  111th Street & Princeton                                 0.03
# 8  103rd Street & Princeton                                 0.72
# 9    111th Street & Western                                 0.07
#
#            Closest Liquor Store  Distance from Closest Liquor Store (km)  \
# 2   MARIO'S WINE & SPIRITS, INC                                     0.51
# 5  DOUBLE R FOOD & LIQUOR, INC.                                     0.64
# 7   115TH ST FOOD & LIQUORS INC                                     0.88
# 8     A & Q FOOD & LIQUOR, INC.                                     0.73
# 9   R. & L. SEARS LIQUORS, INC.                                     0.91
#
#    Square Root of Distance from Closest Police Station (km)  \
# 2                                           2.310844
# 5                                           1.356466
# 7                                           1.452584
# 8                                           1.516575
# 9                                           0.969536
#
#    Square Root of Distance from Closest Bus Stop (km)  \
# 2                                           0.700000
# 5                                           0.173205
# 7                                           0.173205
# 8                                           0.848528
# 9                                           0.264575
#
#    Square Root of Distance from Closest Liquor Store (km)
# 2                                           0.714143
# 5                                           0.800000
# 7                                           0.938083
# 8                                           0.854400
# 9                                           0.953939

# %%
crime_df.columns
# Out:
# Index(['ID', 'Year', 'Primary Type', 'Location Description', 'Domestic',
#        'Beat', 'District', 'Ward', 'Community', 'X Coordinate', 'Y Coordinate',
#        'Latitude', 'Longitude', 'Month', 'Season', 'Quarter of Year',
#        'Day of the Week', 'Day Type', 'Time of Day', 'Day', 'Hour',
#        'Third of Month', 'Holiday', 'Is Holiday', 'Distance from Chicago (km)',
#        'Closest Police Station (District)',
#        'Distance from Closest Police Station (km)', 'Closest Train Stop',
#        'Closest Train Line', 'Distance from Closest Train Stop (km)',
#        'Closest Bus Stop', 'Distance from Closest Bus Stop (km)',
#        'Closest Liquor Store', 'Distance from Closest Liquor Store (km)',
#        'Square Root of Distance from Closest Police Station (km)',
#        'Square Root of Distance from Closest Bus Stop (km)',
#        'Square Root of Distance from Closest Liquor Store (km)'],
#       dtype='object')

# %%
# Setting X and y 
columns = crime_df.columns

primary_cols = 'Primary Type'

other_cols = [c for c in columns if c.startswith(('Location Description', 
       'Beat', 'District', 'Ward', 'Community', 'X Coordinate', 'Y Coordinate', 
        'Latitude', 'Longitude', 'Month', 'Season', 'Quarter of Year',
       'Day of the Week', 'Day Type', 'Time of Day', 'Hour',
       'Holiday', 'Is Holiday', 'Closest Train Line', 'Distance from Closest Train Stop (km)',
       'Distance from Closest Liquor Store (km)',
       'Distance from Chicago (km)', 'Distance from Closest Bus Stop (km)', 
        'Distance from Closest Police Station (km)', 
       'Square Root of Distance from Closest Police Station (km)',
       'Square Root of Distance from Closest Bus Stop (km)', 'Square Root of Distance from Closest Liquor Store (km)'))]       

y_orig = crime_df[primary_cols] # all reports
X_orig = crime_df[other_cols]  

y_sample_3mil = crime_sample_3mil[primary_cols] # 3 million reports
X_sample_3mil = crime_sample_3mil[other_cols]

# %% [markdown]
# ## Saving X, y to files

# %%
X_orig.to_csv('X_orig.csv', index=False)
y_orig.to_csv('y_orig.csv', index=False)

# %%
X_sample_3mil.to_csv('X_sample_3mil.csv', index=False)
y_sample_3mil.to_csv('y_sample_3mil.csv', index=False)
