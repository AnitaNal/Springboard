# %% [markdown]
# Data Source: https://www.kaggle.com/gsnehaa21/federal-holidays-usa-19662020

# %% [markdown]
# In this script I extract and clean federal holidays for 2001-2018 and add to my crime reports df.

# %%
import pandas as pd
import numpy as np

# %%
holiday_df = pd.read_csv('usholidays.csv', parse_dates=['Date'])

# %%
holiday_df.head()
# Out:
#    Unnamed: 0       Date                              Holiday
# 0           0 2010-12-31                       New Year's Day
# 1           1 2011-01-17  Birthday of Martin Luther King, Jr.
# 2           2 2011-02-21                Washington's Birthday
# 3           3 2011-05-30                         Memorial Day
# 4           4 2011-07-04                     Independence Day

# %%
holiday_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 3 columns):
# Unnamed: 0    485 non-null int64
# Date          485 non-null datetime64[ns]
# Holiday       485 non-null object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 11.4+ KB

# %%
# Extracting holidays for only 2001 through 2018
holiday_new = []
for lab, row in holiday_df.iterrows():
    if row['Date'].year in np.arange(2001, 2019):
        holiday_new.append([row['Date'], row['Holiday']])

# %%
# Converting to dataframe
holidays = pd.DataFrame(holiday_new)
holidays.head()
# Out:
#            0                                    1
# 0 2010-12-31                       New Year's Day
# 1 2011-01-17  Birthday of Martin Luther King, Jr.
# 2 2011-02-21                Washington's Birthday
# 3 2011-05-30                         Memorial Day
# 4 2011-07-04                     Independence Day

# %%
# Adding column names
holidays.columns = ['Date', 'Holiday']
holidays.head()
# Out:
#         Date                              Holiday
# 0 2010-12-31                       New Year's Day
# 1 2011-01-17  Birthday of Martin Luther King, Jr.
# 2 2011-02-21                Washington's Birthday
# 3 2011-05-30                         Memorial Day
# 4 2011-07-04                     Independence Day

# %%
# Counting how many holidays in each year
year_count = []
for year in np.arange(2001, 2019): 
    count = 0
    for lab, row in holidays.iterrows():
        if row['Date'].year == year:
            count += 1
    year_count.append([year, count])

# %%
year_count
# Out:
# [[2001, 10],
#  [2002, 10],
#  [2003, 10],
#  [2004, 10],
#  [2005, 10],
#  [2006, 10],
#  [2007, 10],
#  [2008, 10],
#  [2009, 10],
#  [2010, 11],
#  [2011, 9],
#  [2012, 10],
#  [2013, 10],
#  [2014, 10],
#  [2015, 10],
#  [2016, 10],
#  [2017, 10],
#  [2018, 10]]

# %% [markdown]
# All years except for 2010 and 2011 have 10 holidays.

# %%
# Creating a year columns
holidays['Year'] = holidays['Date'].apply(lambda date: date.year)
holidays.head(10)
# Out:
#         Date                              Holiday  Year
# 0 2010-12-31                       New Year's Day  2010
# 1 2011-01-17  Birthday of Martin Luther King, Jr.  2011
# 2 2011-02-21                Washington's Birthday  2011
# 3 2011-05-30                         Memorial Day  2011
# 4 2011-07-04                     Independence Day  2011
# 5 2011-09-05                            Labor Day  2011
# 6 2011-10-10                         Columbus Day  2011
# 7 2011-11-11                         Veterans Day  2011
# 8 2011-11-24                     Thanksgiving Day  2011
# 9 2011-12-26                        Christmas Day  2011

# %%
# Examining holidays in 2010 and 2011
holidays[holidays['Year'] == 2010], holidays[holidays['Year'] == 2011]
# Out:
# (         Date                      Holiday  Year
#  0  2010-12-31               New Year's Day  2010
#  80 2010-01-01               New Year’s Day  2010
#  81 2010-01-18  Martin Luther King, Jr. Day  2010
#  82 2010-02-15        Washington’s Birthday  2010
#  83 2010-05-31                 Memorial Day  2010
#  84 2010-07-05             Independence Day  2010
#  85 2010-09-06                    Labor Day  2010
#  86 2010-10-11                 Columbus Day  2010
#  87 2010-11-11                 Veterans Day  2010
#  88 2010-11-25             Thanksgiving Day  2010
#  89 2010-12-25                Christmas Day  2010,
#          Date                              Holiday  Year
#  1 2011-01-17  Birthday of Martin Luther King, Jr.  2011
#  2 2011-02-21                Washington's Birthday  2011
#  3 2011-05-30                         Memorial Day  2011
#  4 2011-07-04                     Independence Day  2011
#  5 2011-09-05                            Labor Day  2011
#  6 2011-10-10                         Columbus Day  2011
#  7 2011-11-11                         Veterans Day  2011
#  8 2011-11-24                     Thanksgiving Day  2011
#  9 2011-12-26                        Christmas Day  2011)

# %% [markdown]
# The first New Year's Day in 2010 is incorrect and 2011 is missing New Year's Day.  Changing the date below.

# %%
# Changing the date of New Year's Day
holidays.loc[0] = [pd.to_datetime('2011-01-01'), 'New Year\'s Day', 2011]

# %%
# Checking that it is fixed
holidays[holidays['Year'] == 2010], holidays[holidays['Year'] == 2011]
# Out:
# (         Date                      Holiday  Year
#  80 2010-01-01               New Year’s Day  2010
#  81 2010-01-18  Martin Luther King, Jr. Day  2010
#  82 2010-02-15        Washington’s Birthday  2010
#  83 2010-05-31                 Memorial Day  2010
#  84 2010-07-05             Independence Day  2010
#  85 2010-09-06                    Labor Day  2010
#  86 2010-10-11                 Columbus Day  2010
#  87 2010-11-11                 Veterans Day  2010
#  88 2010-11-25             Thanksgiving Day  2010
#  89 2010-12-25                Christmas Day  2010,
#          Date                              Holiday  Year
#  0 2011-01-01                       New Year's Day  2011
#  1 2011-01-17  Birthday of Martin Luther King, Jr.  2011
#  2 2011-02-21                Washington's Birthday  2011
#  3 2011-05-30                         Memorial Day  2011
#  4 2011-07-04                     Independence Day  2011
#  5 2011-09-05                            Labor Day  2011
#  6 2011-10-10                         Columbus Day  2011
#  7 2011-11-11                         Veterans Day  2011
#  8 2011-11-24                     Thanksgiving Day  2011
#  9 2011-12-26                        Christmas Day  2011)

# %%
# Checking out the list of holidays
set(holidays['Holiday'])
# Out:
# {'Birthday of Martin Luther King, Jr.',
#  'Christmas Day',
#  'Columbus Day',
#  'Independence Day',
#  'Labor Day',
#  'Martin Luther King, Jr. Day',
#  'Memorial Day',
#  "New Year's Day",
#  'New Year’s Day',
#  'Thanksgiving Day',
#  'Veterans Day',
#  "Washington's Birthday",
#  'Washington’s Birthday'}

# %% [markdown]
# Martin Luther King, Jr. Day, New Year's Day, and Washington's Birthday have different notations.  I will fix them below.

# %%
# Fixing the holidays
holidays['Holiday'] = holidays['Holiday'].str.replace('New Year’s Day', 'New Year\'s Day')
holidays['Holiday'] = holidays['Holiday'].str.replace('Washington’s Birthday', 'Washington\'s Birthday')
holidays['Holiday'] = holidays['Holiday'].str.replace('Birthday of Martin Luther King, Jr.', 'Martin Luther King, Jr. Day')

# %%
set(holidays['Holiday'])
# Out:
# {'Christmas Day',
#  'Columbus Day',
#  'Independence Day',
#  'Labor Day',
#  'Martin Luther King, Jr. Day',
#  'Memorial Day',
#  "New Year's Day",
#  'Thanksgiving Day',
#  'Veterans Day',
#  "Washington's Birthday"}

# %%
# Saving holiday to csv
holidays.to_csv('holidays.csv', index = False)

# %%
# Reading in the crime data csv file and converting to a dataframe.   
crime_df = pd.read_csv('Crimes_2001_into_2018_Cleaned.csv')

# %%
crime_df.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward        ...         \
# 0               STREET     False  1111      11.0  28.0        ...
# 1               STREET     False   725       7.0  15.0        ...
# 2            APARTMENT      True   222       2.0   4.0        ...
# 3            APARTMENT     False   225       2.0   3.0        ...
# 4             SIDEWALK     False  1113      11.0  28.0        ...
#
#    Month  Season  Quarter of Year  Day of the Week  Day Type  Time of Day Day  \
# 0      3  SPRING               Q1        WEDNESDAY   WEEKDAY      EVENING  18
# 1      3  SPRING               Q1        WEDNESDAY   WEEKDAY      EVENING  18
# 2      3  SPRING               Q1        WEDNESDAY   WEEKDAY      EVENING  18
# 3      3  SPRING               Q1        WEDNESDAY   WEEKDAY      EVENING  18
# 4      3  SPRING               Q1        WEDNESDAY   WEEKDAY      EVENING  18
#
#   Hour Third of Month            Street
# 0   19             T2         W OHIO ST
# 1   23             T2  S MARSHFIELD AVE
# 2   22             T2   S LAKE PARK AVE
# 3   22             T2    S MICHIGAN AVE
# 4   21             T2        W ADAMS ST
#
# [5 rows x 25 columns]

# %%
# Creating a new column with just the date
crime_df['Date2'] = crime_df['Date'].apply(lambda date: date.split(' ')[0])

# %%
# Checking the column was correctly created
crime_df.tail()
# Out:
#                ID                 Date  Year                Block  \
# 6726507  11483642  2015-01-01 00:01:00  2015      034XX W 60TH PL
# 6726508  11483721  2018-10-14 21:15:00  2018    056XX S UNION AVE
# 6726509   2332159  2002-09-05 10:21:00  2002      027XX W 14TH ST
# 6726510     24234  2018-10-15 01:30:00  2018  070XX S PRAIRIE AVE
# 6726511     24235  2018-10-15 11:58:00  2018      017XX W 85TH ST
#
#                        Primary Type     Location Description  Domestic  Beat  \
# 6726507  OFFENSE INVOLVING CHILDREN                RESIDENCE      True   823
# 6726508                     BATTERY                RESIDENCE     False   711
# 6726509                     BATTERY  RESIDENCE PORCH/HALLWAY     False  1023
# 6726510                    HOMICIDE                    HOUSE      True   322
# 6726511                    HOMICIDE                    ALLEY     False   614
#
#          District  Ward     ...      Season  Quarter of Year  Day of the Week  \
# 6726507       8.0  16.0     ...      WINTER               Q1         THURSDAY
# 6726508       7.0  20.0     ...        FALL               Q4           SUNDAY
# 6726509      10.0  28.0     ...        FALL               Q3         THURSDAY
# 6726510       3.0   6.0     ...        FALL               Q4           MONDAY
# 6726511       6.0  18.0     ...        FALL               Q4           MONDAY
#
#          Day Type  Time of Day  Day Hour Third of Month         Street  \
# 6726507   WEEKDAY    OVERNIGHT    1    0             T1      W 60TH PL
# 6726508   WEEKEND      EVENING   14   21             T2    S UNION AVE
# 6726509   WEEKDAY      MORNING    5   10             T1      W 14TH ST
# 6726510   WEEKDAY    OVERNIGHT   15    1             T2  S PRAIRIE AVE
# 6726511   WEEKDAY      MORNING   15   11             T2      W 85TH ST
#
#               Date2
# 6726507  2015-01-01
# 6726508  2018-10-14
# 6726509  2002-09-05
# 6726510  2018-10-15
# 6726511  2018-10-15
#
# [5 rows x 26 columns]

# %%
# Changing the holidays date to string
holidays['Date'] = holidays['Date'].astype('str')

# %%
# Joining holidays with crime_df
crime_df2 = pd.merge(crime_df, holidays[['Date', 'Holiday']], left_on = 'Date2', right_on = 'Date', how = 'left')

# %%
# Checking that the merge was successful
crime_df2[crime_df2['Date2'] == '2014-12-25'][:10]
# Out:
#                ID               Date_x  Year                   Block  \
# 31180    10059140  2014-12-25 09:00:00  2014        064XX S LOWE AVE
# 33924    10064522  2014-12-25 00:01:00  2014  066XX S WINCHESTER AVE
# 734410   10015500  2014-12-25 10:00:00  2014      079XX S RHODES AVE
# 734679   10252432  2014-12-25 07:00:00  2014     055XX S ABERDEEN ST
# 1792978   9909553  2014-12-25 06:30:00  2014         002XX W 72ND ST
# 1793546   9914434  2014-12-25 15:00:00  2014       075XX S COLES AVE
# 1793980   9934478  2014-12-25 12:00:00  2014     002XX N LA SALLE ST
# 1794139   9946912  2014-12-25 08:00:00  2014   016XX N SPAULDING AVE
# 1794404   9976461  2014-12-25 07:00:00  2014     003XX E SUPERIOR ST
# 1794516   9997968  2014-12-25 22:00:00  2014    026XX N LAKEVIEW AVE
#
#                        Primary Type            Location Description  Domestic  \
# 31180                         THEFT                       APARTMENT     False
# 33924                   SEX OFFENSE                       RESIDENCE     False
# 734410                        THEFT  PARKING LOT/GARAGE(NON.RESID.)     False
# 734679   OFFENSE INVOLVING CHILDREN                       RESIDENCE     False
# 1792978         MOTOR VEHICLE THEFT            DRIVEWAY-RESIDENTIAL     False
# 1793546                       THEFT                       APARTMENT     False
# 1793980          DECEPTIVE PRACTICE                           OTHER     False
# 1794139          DECEPTIVE PRACTICE                       RESIDENCE     False
# 1794404               OTHER OFFENSE                           OTHER     False
# 1794516                       THEFT                       RESIDENCE     False
#
#          Beat  District  Ward      ...        Day of the Week  Day Type  \
# 31180     723       7.0  16.0      ...               THURSDAY   WEEKDAY
# 33924     726       7.0  15.0      ...               THURSDAY   WEEKDAY
# 734410    624       6.0   6.0      ...               THURSDAY   WEEKDAY
# 734679    712       7.0  16.0      ...               THURSDAY   WEEKDAY
# 1792978   731       7.0  17.0      ...               THURSDAY   WEEKDAY
# 1793546   421       4.0   7.0      ...               THURSDAY   WEEKDAY
# 1793980   122       1.0  42.0      ...               THURSDAY   WEEKDAY
# 1794139  1422      14.0  26.0      ...               THURSDAY   WEEKDAY
# 1794404  1834      18.0  42.0      ...               THURSDAY   WEEKDAY
# 1794516  1935      19.0  43.0      ...               THURSDAY   WEEKDAY
#
#          Time of Day  Day  Hour  Third of Month            Street       Date2  \
# 31180        MORNING   25     9              T3        S LOWE AVE  2014-12-25
# 33924      OVERNIGHT   25     0              T3  S WINCHESTER AVE  2014-12-25
# 734410       MORNING   25    10              T3      S RHODES AVE  2014-12-25
# 734679       MORNING   25     7              T3     S ABERDEEN ST  2014-12-25
# 1792978      MORNING   25     6              T3         W 72ND ST  2014-12-25
# 1793546    AFTERNOON   25    15              T3       S COLES AVE  2014-12-25
# 1793980    AFTERNOON   25    12              T3     N LA SALLE ST  2014-12-25
# 1794139      MORNING   25     8              T3   N SPAULDING AVE  2014-12-25
# 1794404      MORNING   25     7              T3     E SUPERIOR ST  2014-12-25
# 1794516      EVENING   25    22              T3    N LAKEVIEW AVE  2014-12-25
#
#              Date_y        Holiday
# 31180    2014-12-25  Christmas Day
# 33924    2014-12-25  Christmas Day
# 734410   2014-12-25  Christmas Day
# 734679   2014-12-25  Christmas Day
# 1792978  2014-12-25  Christmas Day
# 1793546  2014-12-25  Christmas Day
# 1793980  2014-12-25  Christmas Day
# 1794139  2014-12-25  Christmas Day
# 1794404  2014-12-25  Christmas Day
# 1794516  2014-12-25  Christmas Day
#
# [10 rows x 28 columns]

# %%
crime_df2.head()
# Out:
#          ID               Date_x  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward   ...    \
# 0               STREET     False  1111      11.0  28.0   ...
# 1               STREET     False   725       7.0  15.0   ...
# 2            APARTMENT      True   222       2.0   4.0   ...
# 3            APARTMENT     False   225       2.0   3.0   ...
# 4             SIDEWALK     False  1113      11.0  28.0   ...
#
#    Day of the Week  Day Type  Time of Day  Day  Hour  Third of Month  \
# 0        WEDNESDAY   WEEKDAY      EVENING   18    19              T2
# 1        WEDNESDAY   WEEKDAY      EVENING   18    23              T2
# 2        WEDNESDAY   WEEKDAY      EVENING   18    22              T2
# 3        WEDNESDAY   WEEKDAY      EVENING   18    22              T2
# 4        WEDNESDAY   WEEKDAY      EVENING   18    21              T2
#
#              Street       Date2 Date_y Holiday
# 0         W OHIO ST  2015-03-18    NaN     NaN
# 1  S MARSHFIELD AVE  2015-03-18    NaN     NaN
# 2   S LAKE PARK AVE  2015-03-18    NaN     NaN
# 3    S MICHIGAN AVE  2015-03-18    NaN     NaN
# 4        W ADAMS ST  2015-03-18    NaN     NaN
#
# [5 rows x 28 columns]

# %%
# Making NaN values in Holiday 'No Holiday'
crime_df2['Holiday'].fillna(value='No Holiday', inplace=True)

# %%
# Adding column to crime_df that says if the day is a federal holiday or not. 
crime_df2['Is Holiday'] = list(map(lambda day: day != 'No Holiday', crime_df2['Holiday']))

# %%
# Removing unneeded columns
del crime_df2['Date2']
del crime_df2['Date_y']

# %%
# Fixing column names
col = ['ID', 'Date', 'Year', 'Block', 'Primary Type', 'Location Description',
       'Domestic', 'Beat', 'District', 'Ward', 'Community', 'X Coordinate',
       'Y Coordinate', 'Latitude', 'Longitude', 'Month', 'Season',
       'Quarter of Year', 'Day of the Week', 'Day Type', 'Time of Day', 'Day',
       'Hour', 'Third of Month', 'Street', 'Holiday', 'Is Holiday']
crime_df2.columns = col

# %%
crime_df2.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward    ...      \
# 0               STREET     False  1111      11.0  28.0    ...
# 1               STREET     False   725       7.0  15.0    ...
# 2            APARTMENT      True   222       2.0   4.0    ...
# 3            APARTMENT     False   225       2.0   3.0    ...
# 4             SIDEWALK     False  1113      11.0  28.0    ...
#
#    Quarter of Year  Day of the Week  Day Type  Time of Day  Day  Hour  \
# 0               Q1        WEDNESDAY   WEEKDAY      EVENING   18    19
# 1               Q1        WEDNESDAY   WEEKDAY      EVENING   18    23
# 2               Q1        WEDNESDAY   WEEKDAY      EVENING   18    22
# 3               Q1        WEDNESDAY   WEEKDAY      EVENING   18    22
# 4               Q1        WEDNESDAY   WEEKDAY      EVENING   18    21
#
#   Third of Month            Street     Holiday Is Holiday
# 0             T2         W OHIO ST  No Holiday      False
# 1             T2  S MARSHFIELD AVE  No Holiday      False
# 2             T2   S LAKE PARK AVE  No Holiday      False
# 3             T2    S MICHIGAN AVE  No Holiday      False
# 4             T2        W ADAMS ST  No Holiday      False
#
# [5 rows x 27 columns]

# %%
# saving crime_df2 to csv
crime_df2.to_csv('Crimes_2001_into_2018_Cleaned.csv', index = False)
