# %% [markdown]
# Data Sources: https://data.cityofchicago.org/Transportation/CTA-Bus-Stops-kml/84eu-buny,
# https://data.cityofchicago.org/Transportation/CTA-System-Information-List-of-L-Stops/8pix-ypme
#
# The bus stops were provided in kmz format.  I used  MyGeodata Converter (https://mygeodata.cloud/converter/) to convert this file to csv.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
from sklearn.neighbors import KDTree, BallTree, DistanceMetric

import matplotlib.pyplot as plt
# %matplotlib inline 
pd.options.display.max_columns = 1000

# %% [markdown]
# ## Bus Stops

# %%
# Reading in bus stop file
bus_df = pd.read_csv('CTA_BusStops.csv')

# %%
bus_df.head()
# Out:
#            X          Y                      Name  description   altitudeMode  \
# 0 -87.612263  41.692670     111th Street & Vernon          NaN  clampToGround
# 1 -87.548627  41.728184   92nd Street & Baltimore          NaN  clampToGround
# 2 -87.737227  41.749111  79th Street & Kilpatrick          NaN  clampToGround
# 3 -87.743974  41.924143    Fullerton & Kilpatrick          NaN  clampToGround
# 4 -87.659294  41.869314           Taylor & Throop          NaN  clampToGround
#
#        STATUS  SYSTEMSTOP OWLROUTES     CITY LEDSIGN POS  \
# 0  In Service        2893       NaN  CHICAGO       0  NS
# 1  In Service       11953       NaN  CHICAGO       0  NS
# 2  In Service        2723       NaN  CHICAGO       0  NS
# 3  In Service        1307       NaN  CHICAGO       0  NS
# 4  In Service        6696       NaN  CHICAGO       0  NS
#
#                 CROSS_ST               PUBLIC_NAME  SHAPE        STREET  \
# 0                 VERNON     111th Street & Vernon  Point  111TH STREET
# 1              BALTIMORE   92nd Street & Baltimore  Point   92ND STREET
# 2  KILPATRICK (east leg)  79th Street & Kilpatrick  Point   79TH STREET
# 3             KILPATRICK    Fullerton & Kilpatrick  Point     FULLERTON
# 4                 THROOP           Taylor & Throop  Point        TAYLOR
#
#      POINT_X    POINT_Y  ADA  ROUTESSTPG DIR                   Field_1
# 0 -87.612263  41.692670    1  4,111A,115  EB     111th Street & Vernon
# 1 -87.548627  41.728184    1          95  EB   92nd Street & Baltimore
# 2 -87.737227  41.749111    1          79  EB  79th Street & Kilpatrick
# 3 -87.743974  41.924143    1          74  EB    Fullerton & Kilpatrick
# 4 -87.659294  41.869314    1         157  EB           Taylor & Throop

# %%
# Checking for null X values
len(bus_df) - len(bus_df['X'].dropna())
# Out:
# 0

# %%
# Checking for null Y values
len(bus_df) - len(bus_df['Y'].dropna())
# Out:
# 0

# %%
# Checking for null bus stop names
len(bus_df) - len(bus_df['Name'].dropna())
# Out:
# 0

# %%
# Selecting only columns I need
bus_df = bus_df[['X', 'Y', 'Name', 'STATUS', 'DIR', 'STREET']]

# Renaming columns
bus_df.columns = ['Longitude', 'Latitude', 'Name', 'Status', 'Direction', 'Street']

# %%
bus_df.head()
# Out:
#    Longitude   Latitude                      Name      Status Direction  \
# 0 -87.612263  41.692670     111th Street & Vernon  In Service        EB
# 1 -87.548627  41.728184   92nd Street & Baltimore  In Service        EB
# 2 -87.737227  41.749111  79th Street & Kilpatrick  In Service        EB
# 3 -87.743974  41.924143    Fullerton & Kilpatrick  In Service        EB
# 4 -87.659294  41.869314           Taylor & Throop  In Service        EB
#
#          Street
# 0  111TH STREET
# 1   92ND STREET
# 2   79TH STREET
# 3     FULLERTON
# 4        TAYLOR

# %%
bus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10916 entries, 0 to 10915
# Data columns (total 6 columns):
# Longitude    10916 non-null float64
# Latitude     10916 non-null float64
# Name         10916 non-null object
# Status       10916 non-null object
# Direction    10916 non-null object
# Street       10916 non-null object
# dtypes: float64(2), object(4)
# memory usage: 511.8+ KB

# %%
# Checking out buses that are not in service
bus_df[bus_df['Status'] != 'In Service'][:10]
# Out:
#      Longitude   Latitude                       Name    Status Direction  \
# 42  -87.683290  42.064170     Central Street & Ridge      Flag        WB
# 69  -87.704665  42.064477    Central Street & Walnut      Flag        WB
# 228 -87.612979  41.765830     71st Street & Eberhart  Temp out        WB
# 244 -87.699090  42.035577                Dodge & Lee      Flag        NB
# 270 -87.685058  42.048401             Church & Maple      Flag        EB
# 284 -87.690196  42.026828            Oakton & Asbury      Flag        WB
# 821 -87.698978  42.042601          Dodge & Greenwood      Flag        NB
# 859 -87.698978  42.055435            Dodge & Simpson      Flag        SB
# 972 -87.695110  42.048304          Church & Florence      Flag        EB
# 985 -87.751584  42.062437  Old Orchard Rd & Lavergne      Flag        EB
#
#              Street
# 42   CENTRAL STREET
# 69   CENTRAL STREET
# 228     71ST STREET
# 244           DODGE
# 270          CHURCH
# 284          OAKTON
# 821           DODGE
# 859           DODGE
# 972          CHURCH
# 985  OLD ORCHARD RD

# %% [markdown]
# A quick search of a few of these bus stops show that they are still in service.  I will therefore keep all of the bus stops.

# %%
# Plotting the lat/long to find any bad positions
plt.scatter(bus_df['Longitude'], bus_df['Latitude'])

# %%
# Checking out the far western stops
bus_df[bus_df['Longitude'] < -87.85]
# Out:
#       Longitude   Latitude                 Name      Status Direction  \
# 882  -87.884297  41.747604  Ups Facility Stop 1  In Service       NEB
# 6652 -87.882337  41.750192  Ups Facility Stop 2  In Service       NEB
#
#             Street
# 882   UPS FACILITY
# 6652  UPS FACILITY

# %% [markdown]
# There are a couple of far western bus stops.  Further investigation shows that they are valid Ups stops.

# %%
# Saving all bus stops to csv
bus_df.to_csv('bus_stops.csv', index = False)

# %% [markdown]
# ## Train Stops

# %%
# Reading in train stop file
train_df = pd.read_csv('CTA_-_System_Information_-_List_of__L__Stops.csv')

# %%
train_df.head()
# Out:
#    STOP_ID DIRECTION_ID                          STOP_NAME  \
# 0    30161            E                  18th (Loop-bound)
# 1    30162            W           18th (54th/Cermak-bound)
# 2    30022            N           35th/Archer (Loop-bound)
# 3    30023            S         35th/Archer (Midway-bound)
# 4    30213            N  35-Bronzeville-IIT (Harlem-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location
# 0  (41.857908, -87.669147)
# 1  (41.857908, -87.669147)
# 2  (41.829353, -87.680622)
# 3  (41.829353, -87.680622)
# 4  (41.831677, -87.625826)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
# STOP_ID                     300 non-null int64
# DIRECTION_ID                300 non-null object
# STOP_NAME                   300 non-null object
# STATION_NAME                300 non-null object
# STATION_DESCRIPTIVE_NAME    300 non-null object
# MAP_ID                      300 non-null int64
# ADA                         300 non-null bool
# RED                         300 non-null bool
# BLUE                        300 non-null bool
# G                           300 non-null bool
# BRN                         300 non-null bool
# P                           300 non-null bool
# Pexp                        300 non-null bool
# Y                           300 non-null bool
# Pnk                         300 non-null bool
# O                           300 non-null bool
# Location                    300 non-null object
# dtypes: bool(10), int64(2), object(5)
# memory usage: 19.4+ KB

# %%
# Creating a new column with just the train line associated with the stop
train_df['LINE'] = train_df['STATION_DESCRIPTIVE_NAME'].apply(lambda name: name.split('(')[1].split(')')[0])

# %%
train_df.tail(10)
# Out:
#      STOP_ID DIRECTION_ID                                     STOP_NAME  \
# 290    30061            S                        Western (Midway-bound)
# 291    30060            N                          Western (Loop-bound)
# 292    30130            S     Western (O'Hare Branch) (Forest Pk-bound)
# 293    30042            E     Western (Forest Pk Branch) (O'Hare-bound)
# 294    30043            W  Western (Forest Pk Branch) (Forest Pk-bound)
# 295    30106            S                           Wilson (95th-bound)
# 296    30105            N                         Wilson (Howard-bound)
# 297    30385            S                           Wilson (Loop-bound)
# 298    30386            N                         Wilson (Linden-bound)
# 299    30033            W            Ashland (Harlem-54th/Cermak-bound)
#
#     STATION_NAME                  STATION_DESCRIPTIVE_NAME  MAP_ID    ADA  \
# 290      Western                     Western (Orange Line)   40310   True
# 291      Western                     Western (Orange Line)   40310   True
# 292      Western       Western (Blue Line - O'Hare Branch)   40670   True
# 293      Western  Western (Blue Line - Forest Park Branch)   40220  False
# 294      Western  Western (Blue Line - Forest Park Branch)   40220  False
# 295       Wilson               Wilson (Red & Purple Lines)   40540   True
# 296       Wilson               Wilson (Red & Purple Lines)   40540   True
# 297       Wilson               Wilson (Red & Purple Lines)   40540   True
# 298       Wilson               Wilson (Red & Purple Lines)   40540   True
# 299      Ashland              Ashland (Green & Pink Lines)   40170   True
#
#        RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 290  False  False  False  False  False  False  False  False   True
# 291  False  False  False  False  False  False  False  False   True
# 292  False   True  False  False  False  False  False  False  False
# 293  False   True  False  False  False  False  False  False  False
# 294  False   True  False  False  False  False  False  False  False
# 295   True  False  False  False  False  False  False  False  False
# 296   True  False  False  False  False  False  False  False  False
# 297  False  False  False  False  False   True  False  False  False
# 298  False  False  False  False  False   True  False  False  False
# 299  False  False   True  False  False  False  False   True  False
#
#                     Location                            LINE
# 290  (41.804546, -87.684019)                     Orange Line
# 291  (41.804546, -87.684019)                     Orange Line
# 292  (41.916157, -87.687364)       Blue Line - O'Hare Branch
# 293  (41.875478, -87.688436)  Blue Line - Forest Park Branch
# 294  (41.875478, -87.688436)  Blue Line - Forest Park Branch
# 295  (41.964273, -87.657588)              Red & Purple Lines
# 296  (41.964273, -87.657588)              Red & Purple Lines
# 297  (41.964273, -87.657588)              Red & Purple Lines
# 298  (41.964273, -87.657588)              Red & Purple Lines
# 299  (41.885269, -87.666969)              Green & Pink Lines

# %%
# Creating new columns for lat/long by splitting the location column
train_df['LATITUDE'] = train_df['Location'].apply(lambda loc: float(loc.split('(')[1].split(', ')[0]))
train_df['LONGITUDE'] = train_df['Location'].apply(lambda loc: float(loc.split('(')[1].split(', ')[1].split(')')[0]))

# %%
train_df.head()
# Out:
#    STOP_ID DIRECTION_ID                          STOP_NAME  \
# 0    30161            E                  18th (Loop-bound)
# 1    30162            W           18th (54th/Cermak-bound)
# 2    30022            N           35th/Archer (Loop-bound)
# 3    30023            S         35th/Archer (Midway-bound)
# 4    30213            N  35-Bronzeville-IIT (Harlem-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location         LINE   LATITUDE  LONGITUDE
# 0  (41.857908, -87.669147)    Pink Line  41.857908 -87.669147
# 1  (41.857908, -87.669147)    Pink Line  41.857908 -87.669147
# 2  (41.829353, -87.680622)  Orange Line  41.829353 -87.680622
# 3  (41.829353, -87.680622)  Orange Line  41.829353 -87.680622
# 4  (41.831677, -87.625826)   Green Line  41.831677 -87.625826

# %%
# Grabbing a few columns and renaming
train_df = train_df[['STOP_NAME', 'DIRECTION_ID', 'STATION_NAME', 'LINE', 'LATITUDE', 'LONGITUDE']]
train_df.columns = ['Stop_Name', 'Direction', 'Station', 'Line', 'Latitude', 'Longitude']

# %%
train_df.head()
# Out:
#                            Stop_Name Direction               Station  \
# 0                  18th (Loop-bound)         E                  18th
# 1           18th (54th/Cermak-bound)         W                  18th
# 2           35th/Archer (Loop-bound)         N           35th/Archer
# 3         35th/Archer (Midway-bound)         S           35th/Archer
# 4  35-Bronzeville-IIT (Harlem-bound)         N  35th-Bronzeville-IIT
#
#           Line   Latitude  Longitude
# 0    Pink Line  41.857908 -87.669147
# 1    Pink Line  41.857908 -87.669147
# 2  Orange Line  41.829353 -87.680622
# 3  Orange Line  41.829353 -87.680622
# 4   Green Line  41.831677 -87.625826

# %%
# Checking unique lines
set(train_df['Line'])
# Out:
# {'Blue Line',
#  'Blue Line - Forest Park Branch',
#  "Blue Line - O'Hare Branch",
#  'Blue, Brown, Green, Orange, Purple & Pink Lines',
#  'Brown & Purple Lines',
#  'Brown Line',
#  'Brown, Green, Orange, Pink & Purple Lines',
#  'Brown, Green, Orange, Purple & Pink Lines',
#  'Brown, Orange, Purple & Pink Lines',
#  'Green & Pink Lines',
#  'Green Line',
#  'Orange Line',
#  'Pink Line',
#  'Purple Line',
#  'Red & Purple Lines',
#  'Red Line',
#  'Red, Brown & Purple Lines',
#  'Red, Orange & Green Lines',
#  'Red, Purple & Yellow Lines',
#  'Yellow Line'}

# %% [markdown]
# I will leave the line names as is for now.

# %%
# Checking for any bad lat/long points
plt.scatter(train_df['Longitude'], train_df['Latitude'])

# %%
# Saving all train stops to csv
train_df.to_csv('train_stops.csv', index = False)

# %% [markdown]
# ## Distance from Nearest Train Stop

# %%
# Reading in crime data
crime_df = pd.read_csv('Crimes_2001_into_2018_Cleaned.csv')

# %%
crime_df.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday
# 0             T2         W OHIO ST  No Holiday       False
# 1             T2  S MARSHFIELD AVE  No Holiday       False
# 2             T2   S LAKE PARK AVE  No Holiday       False
# 3             T2    S MICHIGAN AVE  No Holiday       False
# 4             T2        W ADAMS ST  No Holiday       False

# %%
# Creating a temporary dataframe with non-null entries of latitude and longitude
crime_df_notnull = crime_df[pd.notnull(crime_df['Latitude'])]

# Resetting the index for crime_df_notnull before moving on
crime_df_notnull = crime_df_notnull.reset_index(drop = True)

# %%
# Converting the train stop coordinates to radians and zipping them together 
train = list(zip(np.deg2rad(train_df['Latitude']), np.deg2rad(train_df['Longitude'])))

# The BallTree is created using the train stop coordinates
tree = BallTree(train, metric = DistanceMetric.get_metric('haversine'))

# Converting the crime coordinates to radians and zipping them together
crime = list(zip(np.deg2rad(crime_df_notnull['Latitude']), np.deg2rad(crime_df_notnull['Longitude'])))

# %%
# Finding the closest train stop for each crime (splitting in half to reduce run time)
dists, ind = tree.query(crime[0:3333088], k=1) # returns distance and index of nearest train stop
dists2, ind2 = tree.query(crime[3333088:], k=1)

# %%
# Combining dists and ind
dists_all = np.vstack([dists, dists2])
ind_all = np.vstack([ind, ind2])

# Extracting the nearest train stop name from ind_all
index_train = list(ind_all[:,0])
stops_train = list(train_df['Station'][index_train])
line_train = list(train_df['Line'][index_train])

# Extracting the distance from the nearest train stop from dists_all and converting from radians to km
distances_train = list((dists_all[:,0] * 6371).round(2))

# %%
# Creating new columns
crime_df_notnull['Closest Train Stop'] = stops_train
crime_df_notnull['Closest Train Line'] = line_train
crime_df_notnull['Distance from Closest Train Stop (km)'] = distances_train

# %%
len(ind_all) - len(crime_df_notnull)
# Out:
# 0

# %%
crime_df_notnull.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74

# %% [markdown]
# ## Distance from Nearest Bus Stop

# %%
bus_df.head()
# Out:
#    Longitude   Latitude                      Name      Status Direction  \
# 0 -87.612263  41.692670     111th Street & Vernon  In Service        EB
# 1 -87.548627  41.728184   92nd Street & Baltimore  In Service        EB
# 2 -87.737227  41.749111  79th Street & Kilpatrick  In Service        EB
# 3 -87.743974  41.924143    Fullerton & Kilpatrick  In Service        EB
# 4 -87.659294  41.869314           Taylor & Throop  In Service        EB
#
#          Street
# 0  111TH STREET
# 1   92ND STREET
# 2   79TH STREET
# 3     FULLERTON
# 4        TAYLOR

# %%
# Converting the bus stop coordinates to radians and zipping them together 
bus = list(zip(np.deg2rad(bus_df['Latitude']), np.deg2rad(bus_df['Longitude'])))

# The BallTree is created using the bus stop coordinates
tree = BallTree(bus, metric = DistanceMetric.get_metric('haversine'))

# %%
# Finding the closest bus stop for each crime - splitting in two to reduce run time
dists, ind = tree.query(crime[0:3333088], k=1) # returns distance and index of nearest bus stop
dists2, ind2 = tree.query(crime[3333088:], k=1)

# %%
# Combining dists and ind
dists_all = np.vstack([dists, dists2])
ind_all = np.vstack([ind, ind2])

# Extracting the nearest bus stop name from ind_all
index_bus = list(ind_all[:,0])
stops_bus = list(bus_df['Name'][index_bus])

# Extracting the distance from the nearest bus stop from dists_all and converting from radians to km
distances_bus = list((dists_all[:,0] * 6371).round(2))

# %%
# Creating new columns
crime_df_notnull['Closest Bus Stop'] = stops_bus
crime_df_notnull['Distance from Closest Bus Stop (km)'] = distances_bus

# %%
crime_df_notnull.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13

# %%
crime_df_notnull.columns
# Out:
# Index(['ID', 'Date', 'Year', 'Block', 'Primary Type', 'Location Description',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community', 'X Coordinate',
#        'Y Coordinate', 'Latitude', 'Longitude', 'Month', 'Season',
#        'Quarter of Year', 'Day of the Week', 'Day Type', 'Time of Day', 'Day',
#        'Hour', 'Third of Month', 'Street', 'Holiday', 'Is Holiday',
#        'Closest Train Stop', 'Closest Train Line',
#        'Distance from Closest Train Stop (km)', 'Closest Bus Stop',
#        'Distance from Closest Bus Stop (km)'],
#       dtype='object')

# %%
# Joining crime_df_notnull with crime_df
crime_df2 = pd.merge(crime_df, crime_df_notnull[['ID', 'Closest Train Stop', 'Closest Train Line', 'Distance from Closest Train Stop (km)', 
                                                 'Closest Bus Stop', 'Distance from Closest Bus Stop (km)' ]], left_on = 'ID', right_on = 'ID', how = 'left')

# %%
crime_df2.head()
# Out:
#          ID                 Date  Year                   Block   Primary Type  \
# 0  10000092  2015-03-18 19:44:00  2015         047XX W OHIO ST        BATTERY
# 1  10000094  2015-03-18 23:00:00  2015  066XX S MARSHFIELD AVE  OTHER OFFENSE
# 2  10000095  2015-03-18 22:45:00  2015   044XX S LAKE PARK AVE        BATTERY
# 3  10000096  2015-03-18 22:30:00  2015    051XX S MICHIGAN AVE        BATTERY
# 4  10000097  2015-03-18 21:00:00  2015        047XX W ADAMS ST        ROBBERY
#
#   Location Description  Domestic  Beat  District  Ward  Community  \
# 0               STREET     False  1111      11.0  28.0       25.0
# 1               STREET     False   725       7.0  15.0       67.0
# 2            APARTMENT      True   222       2.0   4.0       39.0
# 3            APARTMENT     False   225       2.0   3.0       40.0
# 4             SIDEWALK     False  1113      11.0  28.0       25.0
#
#    X Coordinate  Y Coordinate   Latitude  Longitude  Month  Season  \
# 0     1144606.0     1903566.0  41.891399 -87.744385      3  SPRING
# 1     1166468.0     1860715.0  41.773372 -87.665319      3  SPRING
# 2     1185075.0     1875622.0  41.813861 -87.596643      3  SPRING
# 3     1178033.0     1870804.0  41.800802 -87.622619      3  SPRING
# 4     1144920.0     1898709.0  41.878065 -87.743354      3  SPRING
#
#   Quarter of Year Day of the Week Day Type Time of Day  Day  Hour  \
# 0              Q1       WEDNESDAY  WEEKDAY     EVENING   18    19
# 1              Q1       WEDNESDAY  WEEKDAY     EVENING   18    23
# 2              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 3              Q1       WEDNESDAY  WEEKDAY     EVENING   18    22
# 4              Q1       WEDNESDAY  WEEKDAY     EVENING   18    21
#
#   Third of Month            Street     Holiday  Is Holiday Closest Train Stop  \
# 0             T2         W OHIO ST  No Holiday       False             Cicero
# 1             T2  S MARSHFIELD AVE  No Holiday       False       Ashland/63rd
# 2             T2   S LAKE PARK AVE  No Holiday       False               43rd
# 3             T2    S MICHIGAN AVE  No Holiday       False               51st
# 4             T2        W ADAMS ST  No Holiday       False             Cicero
#
#   Closest Train Line  Distance from Closest Train Stop (km)  \
# 0         Green Line                                   0.54
# 1         Green Line                                   0.62
# 2         Green Line                                   1.88
# 3         Green Line                                   0.37
# 4          Blue Line                                   0.74
#
#           Closest Bus Stop  Distance from Closest Bus Stop (km)
# 0            Cicero & Ohio                                 0.10
# 1    Ashland & 66th Street                                 0.12
# 2  Oakenwald & 43rd Street                                 0.35
# 3   51st Street & Michigan                                 0.13
# 4     Jackson & Kilpatrick                                 0.13

# %%
len(crime_df) - len(crime_df.dropna())
# Out:
# 669928

# %%
len(crime_df2) - len(crime_df2.dropna())
# Out:
# 669928

# %%
# Saving crime_df2 to csv
crime_df2.to_csv('Crimes_2001_into_2018_Cleaned.csv', index = False)
